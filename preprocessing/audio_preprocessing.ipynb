# %% [markdown]
# <a href="https://colab.research.google.com/github/roxyrong/emotion_detection/blob/main/Feature_Extraction_and_Combination_(New).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import modules for google cloud
from google.colab import auth
from google.cloud import storage
auth.authenticate_user()
client = storage.Client()

import math
import scipy as sp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio, display

# %%
# === connect to SAVEE dataset
bucket = client.get_bucket('savee')
blob = bucket.blob('augmented_dataset.npy')
blob.download_to_filename('augmented_dataset.npy')
blob = bucket.blob('augmented_dataset.csv')
blob.download_to_filename('augmented_dataset.csv')

# %%
# === Function: Convert npy to dataframe
def load_data(npy_data_path,csv_data_path):
    '''

    :param npy_data_path: NPY data Path
    :param csv_data_path:  CSV data Path
    :return: feature extraction dataframe
    '''
    audio_feature_file = np.load(file=npy_data_path,allow_pickle=True)
    data = pd.read_csv(csv_data_path)
    column_list = data.columns.to_list()
    augmented_data = pd.DataFrame(columns = column_list)
    for i in range(0,len(audio_feature_file)):
        row_list = []
        for item in range(0,len(column_list)):
            row_list.append(audio_feature_file[i][item])
        augmented_data.loc[len(augmented_data)+1] = row_list
    print(augmented_data.info())
    return augmented_data

# %%
df = load_data('augmented_dataset.npy', 'augmented_dataset.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1920 entries, 1 to 1920
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   data       1920 non-null   object
#  1   path       1920 non-null   object
#  2   dataset    1920 non-null   object
#  3   emotion    1920 non-null   object
#  4   speaker    1920 non-null   object
#  5   augmented  1920 non-null   bool
# dtypes: bool(1), object(5)
# memory usage: 91.9+ KB
# None

# %%
### ====Setup Constant

SAMPLE_RATE = 22050
FRAME_SIZE = 2048
HOP_SIZE = 512

SPLIT_FREQ = 2000
F_MAX = 8000

# %%
### === Features Util Function

# AE
def amplitude_envelope(signal, frame_size, hop_length):
    return np.array([max(signal[i:i+frame_size]) for i in range(0, len(signal), hop_length)])

# BER
def calculate_split_frequency_bin(split_frequency, sample_rate, num_frequency_bins):
    """Infer the frequency bin associated to a given split frequency."""
    
    frequency_range = sample_rate / 2
    frequency_delta_per_bin = frequency_range / num_frequency_bins
    split_frequency_bin = math.floor(split_frequency / frequency_delta_per_bin)
    return int(split_frequency_bin)

def band_energy_ratio(spectrogram, split_frequency, sample_rate):
    """Calculate band energy ratio with a given split frequency."""
    
    split_frequency_bin = calculate_split_frequency_bin(split_frequency, sample_rate, len(spectrogram[0]))
    band_energy_ratio = []
    

    # calculate power spectrogram
    power_spectrogram = np.abs(spectrogram) ** 2
    power_spectrogram = power_spectrogram.T
    
    # calculate BER value for each frame
    for frame in power_spectrogram:
        sum_power_low_frequencies = frame[:split_frequency_bin].sum()
        sum_power_high_frequencies = frame[split_frequency_bin:].sum()
        band_energy_ratio_current_frame = sum_power_low_frequencies / sum_power_high_frequencies
        band_energy_ratio.append(band_energy_ratio_current_frame)
    
    return np.array(band_energy_ratio)

# teager
def teager_energy_operator(y):
    """Compute the Teager Energy Operator (TEO) for a given signal."""
    teo = np.zeros_like(y)
    teo[1:-1] = y[1:-1]**2 - y[:-2] * y[2:]
    return teo

# %%
features_dict = {}
for id, row in df.iterrows():
  temp_data = row['data']
  temp_data = librosa.effects.trim(temp_data, top_db=10)[0]

  path = row['path']
  print('process ' + path)
  row_dict = {}


### === Prosodic features - frequency

  # fundamental frequency f0
  f0, _, _ = librosa.pyin(temp_data, sr=SAMPLE_RATE, 
                          frame_length=FRAME_SIZE, hop_length=HOP_SIZE, 
                          fmin=librosa.note_to_hz('C2'), 
                          fmax=librosa.note_to_hz('C7')
                          ,fill_na=librosa.note_to_hz('C2'))
  row_dict['f0'] = f0
  
  # pitch features
  row_dict['pitch_mean'] = np.mean(f0)
  row_dict['pitch_median'] = np.median(f0)
  row_dict['pitch_std'] = np.std(f0)
  row_dict['pitch_range'] = np.max(f0) - np.min(f0)
  row_dict['pitch_max'] = max(f0)


### === Prosodic features: amplitude 

  # loudness
  S, phase = librosa.magphase(librosa.stft(temp_data))
  rms = librosa.feature.rms(S=S)[0]

  # loudness features
  row_dict['energy_mean'] = np.mean(rms)
  row_dict['energy_median'] = np.median(rms)
  row_dict['energy_std']= np.std(rms)
  row_dict['energy_range'] = np.max(rms) - np.min(rms)
  row_dict['energy_max'] = np.max(rms)


### === Prosodic features: Jitter & Shimmer
  # Jitter
  row_dict['jitter'] = np.mean(np.abs(np.diff(f0)))

  # Shimmer
  row_dict['shimmer'] = np.mean(np.abs(np.diff(20 * np.log10(rms))))



### === Time Domain Features: 
  # Amplitude Envelope
  row_dict['amplitude_envelope'] = amplitude_envelope(temp_data, FRAME_SIZE, HOP_SIZE)
  # Root Mean Square
  row_dict['rms'] = rms
  # Zero Crossing Rate (ZCR)
  row_dict['zcr']= librosa.feature.zero_crossing_rate(temp_data, 
                                                      frame_length=FRAME_SIZE, 
                                                      hop_length=HOP_SIZE)[0]


### === Frequency Domain Features: 

  # Band Energy Ratio (BER) - split at 2000 Hz
  spec = librosa.stft(temp_data, n_fft=FRAME_SIZE, hop_length=HOP_SIZE) # spectrogram
  row_dict['ber'] = band_energy_ratio(spec, SPLIT_FREQ, SAMPLE_RATE)

  # Amplitude Spectrogram
  row_dict['amplitude_spectrogram'] = spec
  # Decible Spectrogram
  row_dict['dB_spectrogram'] = librosa.amplitude_to_db(abs(spec), ref=np.max)

  # Spectral Contrast (2D)
  row_dict['spec_contrast'] = librosa.feature.spectral_contrast(S=spec, 
                                                                sr=SAMPLE_RATE)

  # Spectral Flux (2D)
  row_dict['spec_flux'] = librosa.onset.onset_strength(y=temp_data, sr=SAMPLE_RATE, 
                                                       aggregate=np.median, 
                                                       fmax=F_MAX, n_mels=128)
  
  # Spectral Centroid (1D)
  row_dict['spec_centroid'] = librosa.feature.spectral_centroid(y=temp_data, 
                                                                sr=SAMPLE_RATE, 
                                                                n_fft=FRAME_SIZE, 
                                                                hop_length=HOP_SIZE)[0]

  # Spectral Bandwidth (1D)
  row_dict['spec_bandwidth']= librosa.feature.spectral_bandwidth(y=temp_data, 
                                                                 sr=SAMPLE_RATE, 
                                                                 n_fft=FRAME_SIZE, 
                                                                 hop_length=HOP_SIZE)[0]

  # Spectral Flatnexx (1D)
  row_dict['spec_flatness'] = librosa.feature.spectral_flatness(y=temp_data,
                                                                n_fft=FRAME_SIZE, 
                                                                hop_length=HOP_SIZE)[0]


### === Spectrograms

  # power_spetrogram
  stft = librosa.core.stft(temp_data, n_fft = FRAME_SIZE, hop_length = HOP_SIZE)
  row_dict['power_spetrogram'] = librosa.amplitude_to_db(abs(stft))

  # mel_spectrogram
  y_stft = librosa.power_to_db(np.abs(stft) ** 2)
  mel_spec = librosa.feature.melspectrogram(S=y_stft, sr=SAMPLE_RATE, 
                                            n_fft=FRAME_SIZE, 
                                            hop_length=HOP_SIZE, 
                                            n_mels=128)
  row_dict['mel_spetrogram'] = mel_spec
  
  # mel_db_spectrogram
  mel_spec_dB = librosa.power_to_db(mel_spec, ref=np.max)
  row_dict['mel_dB_spectrogram'] = mel_spec_dB


### === MFCCs
  mfcc = librosa.feature.mfcc(y=temp_data, n_mfcc=40, sr=SAMPLE_RATE)
  row_dict['mfcc'] = mfcc

  mfcc_delta = librosa.feature.delta(mfcc)
  row_dict['mfcc_delta'] = mfcc_delta

  mfcc_delta_2 = librosa.feature.delta(mfcc , order=2)
  row_dict['mfcc_delta'] = mfcc_delta_2


### === Teager Energy Operator
  teager_energy = teager_energy_operator(temp_data)
  row_dict['teo'] = teager_energy


  features_dict[id] = row_dict
# Out:
# process AudioData/DC/a01.wav
# /usr/local/lib/python3.9/dist-packages/librosa/feature/spectral.py:523: ComplexWarning: Casting complex values to real discards the imaginary part
#   valley[..., k, :] = np.mean(sortedr[..., :idx, :], axis=-2)
# /usr/local/lib/python3.9/dist-packages/librosa/feature/spectral.py:524: ComplexWarning: Casting complex values to real discards the imaginary part
#   peak[..., k, :] = np.mean(sortedr[..., -idx:, :], axis=-2)
# process AudioData/DC/a02.wav
# process AudioData/DC/a03.wav
# process AudioData/DC/a04.wav
# process AudioData/DC/a05.wav
# process AudioData/DC/a06.wav
# process AudioData/DC/a07.wav
# process AudioData/DC/a08.wav
# process AudioData/DC/a09.wav
# process AudioData/DC/a10.wav
# process AudioData/DC/a11.wav
# process AudioData/DC/a12.wav
# process AudioData/DC/a13.wav
# process AudioData/DC/a14.wav
# process AudioData/DC/a15.wav
# process AudioData/DC/d01.wav
# process AudioData/DC/d02.wav
# process AudioData/DC/d03.wav
# process AudioData/DC/d04.wav
# process AudioData/DC/d05.wav
# process AudioData/DC/d06.wav
# process AudioData/DC/d07.wav
# process AudioData/DC/d08.wav
# process AudioData/DC/d09.wav
# process AudioData/DC/d10.wav
# process AudioData/DC/d11.wav
# process AudioData/DC/d12.wav
# process AudioData/DC/d13.wav
# process AudioData/DC/d14.wav
# process AudioData/DC/d15.wav
# process AudioData/DC/f01.wav
# process AudioData/DC/f02.wav
# process AudioData/DC/f03.wav
# process AudioData/DC/f04.wav
# process AudioData/DC/f05.wav
# process AudioData/DC/f06.wav
# process AudioData/DC/f07.wav
# process AudioData/DC/f08.wav
# process AudioData/DC/f09.wav
# process AudioData/DC/f10.wav
# process AudioData/DC/f11.wav
# process AudioData/DC/f12.wav
# process AudioData/DC/f13.wav
# process AudioData/DC/f14.wav
# process AudioData/DC/f15.wav
# process AudioData/DC/h01.wav
# process AudioData/DC/h02.wav
# process AudioData/DC/h03.wav
# process AudioData/DC/h04.wav
# process AudioData/DC/h05.wav
# process AudioData/DC/h06.wav
# process AudioData/DC/h07.wav
# process AudioData/DC/h08.wav
# process AudioData/DC/h09.wav
# process AudioData/DC/h10.wav
# process AudioData/DC/h11.wav
# process AudioData/DC/h12.wav
# process AudioData/DC/h13.wav
# process AudioData/DC/h14.wav
# process AudioData/DC/h15.wav
# process AudioData/DC/n01.wav
# process AudioData/DC/n02.wav
# process AudioData/DC/n03.wav
# process AudioData/DC/n04.wav
# process AudioData/DC/n05.wav
# process AudioData/DC/n06.wav
# process AudioData/DC/n07.wav
# process AudioData/DC/n08.wav
# process AudioData/DC/n09.wav
# process AudioData/DC/n10.wav
# process AudioData/DC/n11.wav
# process AudioData/DC/n12.wav
# process AudioData/DC/n13.wav
# process AudioData/DC/n14.wav
# process AudioData/DC/n15.wav
# process AudioData/DC/n16.wav
# process AudioData/DC/n17.wav
# process AudioData/DC/n18.wav
# process AudioData/DC/n19.wav
# process AudioData/DC/n20.wav
# process AudioData/DC/n21.wav
# process AudioData/DC/n22.wav
# process AudioData/DC/n23.wav
# process AudioData/DC/n24.wav
# process AudioData/DC/n25.wav
# process AudioData/DC/n26.wav
# process AudioData/DC/n27.wav
# process AudioData/DC/n28.wav
# process AudioData/DC/n29.wav
# process AudioData/DC/n30.wav
# process AudioData/DC/sa01.wav
# process AudioData/DC/sa02.wav
# process AudioData/DC/sa03.wav
# process AudioData/DC/sa04.wav
# process AudioData/DC/sa05.wav
# process AudioData/DC/sa06.wav
# process AudioData/DC/sa07.wav
# process AudioData/DC/sa08.wav
# process AudioData/DC/sa09.wav
# process AudioData/DC/sa10.wav
# process AudioData/DC/sa11.wav
# process AudioData/DC/sa12.wav
# process AudioData/DC/sa13.wav
# process AudioData/DC/sa14.wav
# process AudioData/DC/sa15.wav
# process AudioData/DC/su01.wav
# process AudioData/DC/su02.wav
# process AudioData/DC/su03.wav
# process AudioData/DC/su04.wav
# process AudioData/DC/su05.wav
# process AudioData/DC/su06.wav
# process AudioData/DC/su07.wav
# process AudioData/DC/su08.wav
# process AudioData/DC/su09.wav
# process AudioData/DC/su10.wav
# process AudioData/DC/su11.wav
# process AudioData/DC/su12.wav
# process AudioData/DC/su13.wav
# process AudioData/DC/su14.wav
# process AudioData/DC/su15.wav
# process AudioData/JE/a01.wav
# process AudioData/JE/a02.wav
# process AudioData/JE/a03.wav
# process AudioData/JE/a04.wav
# process AudioData/JE/a05.wav
# process AudioData/JE/a06.wav
# process AudioData/JE/a07.wav
# process AudioData/JE/a08.wav
# process AudioData/JE/a09.wav
# process AudioData/JE/a10.wav
# process AudioData/JE/a11.wav
# process AudioData/JE/a12.wav
# process AudioData/JE/a13.wav
# process AudioData/JE/a14.wav
# process AudioData/JE/a15.wav
# process AudioData/JE/d01.wav
# process AudioData/JE/d02.wav
# process AudioData/JE/d03.wav
# process AudioData/JE/d04.wav
# process AudioData/JE/d05.wav
# process AudioData/JE/d06.wav
# process AudioData/JE/d07.wav
# process AudioData/JE/d08.wav
# process AudioData/JE/d09.wav
# process AudioData/JE/d10.wav
# process AudioData/JE/d11.wav
# process AudioData/JE/d12.wav
# process AudioData/JE/d13.wav
# process AudioData/JE/d14.wav
# process AudioData/JE/d15.wav
# process AudioData/JE/f01.wav
# process AudioData/JE/f02.wav
# process AudioData/JE/f03.wav
# process AudioData/JE/f04.wav
# process AudioData/JE/f05.wav
# process AudioData/JE/f06.wav
# process AudioData/JE/f07.wav
# process AudioData/JE/f08.wav
# process AudioData/JE/f09.wav
# process AudioData/JE/f10.wav
# process AudioData/JE/f11.wav
# process AudioData/JE/f12.wav
# process AudioData/JE/f13.wav
# process AudioData/JE/f14.wav
# process AudioData/JE/f15.wav
# process AudioData/JE/h01.wav
# process AudioData/JE/h02.wav
# process AudioData/JE/h03.wav
# process AudioData/JE/h04.wav
# process AudioData/JE/h05.wav
# process AudioData/JE/h06.wav
# process AudioData/JE/h07.wav
# process AudioData/JE/h08.wav
# process AudioData/JE/h09.wav
# process AudioData/JE/h10.wav
# process AudioData/JE/h11.wav
# process AudioData/JE/h12.wav
# process AudioData/JE/h13.wav
# process AudioData/JE/h14.wav
# process AudioData/JE/h15.wav
# process AudioData/JE/n01.wav
# process AudioData/JE/n02.wav
# process AudioData/JE/n03.wav
# process AudioData/JE/n04.wav
# process AudioData/JE/n05.wav
# process AudioData/JE/n06.wav
# process AudioData/JE/n07.wav
# process AudioData/JE/n08.wav
# process AudioData/JE/n09.wav
# process AudioData/JE/n10.wav
# process AudioData/JE/n11.wav
# process AudioData/JE/n12.wav
# process AudioData/JE/n13.wav
# process AudioData/JE/n14.wav
# process AudioData/JE/n15.wav
# process AudioData/JE/n16.wav
# process AudioData/JE/n17.wav
# process AudioData/JE/n18.wav
# process AudioData/JE/n19.wav
# process AudioData/JE/n20.wav
# process AudioData/JE/n21.wav
# process AudioData/JE/n22.wav
# process AudioData/JE/n23.wav
# process AudioData/JE/n24.wav
# process AudioData/JE/n25.wav
# process AudioData/JE/n26.wav
# process AudioData/JE/n27.wav
# process AudioData/JE/n28.wav
# process AudioData/JE/n29.wav
# process AudioData/JE/n30.wav
# process AudioData/JE/sa01.wav
# process AudioData/JE/sa02.wav
# process AudioData/JE/sa03.wav
# process AudioData/JE/sa04.wav
# process AudioData/JE/sa05.wav
# process AudioData/JE/sa06.wav
# process AudioData/JE/sa07.wav
# process AudioData/JE/sa08.wav
# process AudioData/JE/sa09.wav
# process AudioData/JE/sa10.wav
# process AudioData/JE/sa11.wav
# process AudioData/JE/sa12.wav
# process AudioData/JE/sa13.wav
# process AudioData/JE/sa14.wav
# process AudioData/JE/sa15.wav
# process AudioData/JE/su01.wav
# process AudioData/JE/su02.wav
# process AudioData/JE/su03.wav
# process AudioData/JE/su04.wav
# process AudioData/JE/su05.wav
# process AudioData/JE/su06.wav
# process AudioData/JE/su07.wav
# process AudioData/JE/su08.wav
# process AudioData/JE/su09.wav
# process AudioData/JE/su10.wav
# process AudioData/JE/su11.wav
# process AudioData/JE/su12.wav
# process AudioData/JE/su13.wav
# process AudioData/JE/su14.wav
# process AudioData/JE/su15.wav
# process AudioData/JK/a01.wav
# process AudioData/JK/a02.wav
# process AudioData/JK/a03.wav
# process AudioData/JK/a04.wav
# process AudioData/JK/a05.wav
# process AudioData/JK/a06.wav
# process AudioData/JK/a07.wav
# process AudioData/JK/a08.wav
# process AudioData/JK/a09.wav
# process AudioData/JK/a10.wav
# process AudioData/JK/a11.wav
# process AudioData/JK/a12.wav
# process AudioData/JK/a13.wav
# process AudioData/JK/a14.wav
# process AudioData/JK/a15.wav
# process AudioData/JK/d01.wav
# process AudioData/JK/d02.wav
# process AudioData/JK/d03.wav
# process AudioData/JK/d04.wav
# process AudioData/JK/d05.wav
# process AudioData/JK/d06.wav
# process AudioData/JK/d07.wav
# process AudioData/JK/d08.wav
# process AudioData/JK/d09.wav
# process AudioData/JK/d10.wav
# process AudioData/JK/d11.wav
# process AudioData/JK/d12.wav
# process AudioData/JK/d13.wav
# process AudioData/JK/d14.wav
# process AudioData/JK/d15.wav
# process AudioData/JK/f01.wav
# process AudioData/JK/f02.wav
# process AudioData/JK/f03.wav
# process AudioData/JK/f04.wav
# process AudioData/JK/f05.wav
# process AudioData/JK/f06.wav
# process AudioData/JK/f07.wav
# process AudioData/JK/f08.wav
# process AudioData/JK/f09.wav
# process AudioData/JK/f10.wav
# process AudioData/JK/f11.wav
# process AudioData/JK/f12.wav
# process AudioData/JK/f13.wav
# process AudioData/JK/f14.wav
# process AudioData/JK/f15.wav
# process AudioData/JK/h01.wav
# process AudioData/JK/h02.wav
# process AudioData/JK/h03.wav
# process AudioData/JK/h04.wav
# process AudioData/JK/h05.wav
# process AudioData/JK/h06.wav
# process AudioData/JK/h07.wav
# process AudioData/JK/h08.wav
# process AudioData/JK/h09.wav
# process AudioData/JK/h10.wav
# process AudioData/JK/h11.wav
# process AudioData/JK/h12.wav
# process AudioData/JK/h13.wav
# process AudioData/JK/h14.wav
# process AudioData/JK/h15.wav
# process AudioData/JK/n01.wav
# process AudioData/JK/n02.wav
# process AudioData/JK/n03.wav
# process AudioData/JK/n04.wav
# process AudioData/JK/n05.wav
# process AudioData/JK/n06.wav
# process AudioData/JK/n07.wav
# process AudioData/JK/n08.wav
# process AudioData/JK/n09.wav
# process AudioData/JK/n10.wav
# process AudioData/JK/n11.wav
# process AudioData/JK/n12.wav
# process AudioData/JK/n13.wav
# process AudioData/JK/n14.wav
# process AudioData/JK/n15.wav
# process AudioData/JK/n16.wav
# process AudioData/JK/n17.wav
# process AudioData/JK/n18.wav
# process AudioData/JK/n19.wav
# process AudioData/JK/n20.wav
# process AudioData/JK/n21.wav
# process AudioData/JK/n22.wav
# process AudioData/JK/n23.wav
# process AudioData/JK/n24.wav
# process AudioData/JK/n25.wav
# process AudioData/JK/n26.wav
# process AudioData/JK/n27.wav
# process AudioData/JK/n28.wav
# process AudioData/JK/n29.wav
# process AudioData/JK/n30.wav
# process AudioData/JK/sa01.wav
# process AudioData/JK/sa02.wav
# process AudioData/JK/sa03.wav
# process AudioData/JK/sa04.wav
# process AudioData/JK/sa05.wav
# process AudioData/JK/sa06.wav
# process AudioData/JK/sa07.wav
# process AudioData/JK/sa08.wav
# process AudioData/JK/sa09.wav
# process AudioData/JK/sa10.wav
# process AudioData/JK/sa11.wav
# process AudioData/JK/sa12.wav
# process AudioData/JK/sa13.wav
# process AudioData/JK/sa14.wav
# process AudioData/JK/sa15.wav
# process AudioData/JK/su01.wav
# process AudioData/JK/su02.wav
# process AudioData/JK/su03.wav
# process AudioData/JK/su04.wav
# process AudioData/JK/su05.wav
# process AudioData/JK/su06.wav
# process AudioData/JK/su07.wav
# process AudioData/JK/su08.wav
# process AudioData/JK/su09.wav
# process AudioData/JK/su10.wav
# process AudioData/JK/su11.wav
# process AudioData/JK/su12.wav
# process AudioData/JK/su13.wav
# process AudioData/JK/su14.wav
# process AudioData/JK/su15.wav
# process AudioData/KL/a01.wav
# process AudioData/KL/a02.wav
# process AudioData/KL/a03.wav
# process AudioData/KL/a04.wav
# process AudioData/KL/a05.wav
# process AudioData/KL/a06.wav
# process AudioData/KL/a07.wav
# process AudioData/KL/a08.wav
# process AudioData/KL/a09.wav
# process AudioData/KL/a10.wav
# process AudioData/KL/a11.wav
# process AudioData/KL/a12.wav
# process AudioData/KL/a13.wav
# process AudioData/KL/a14.wav
# process AudioData/KL/a15.wav
# process AudioData/KL/d01.wav
# process AudioData/KL/d02.wav
# process AudioData/KL/d03.wav
# process AudioData/KL/d04.wav
# process AudioData/KL/d05.wav
# process AudioData/KL/d06.wav
# process AudioData/KL/d07.wav
# process AudioData/KL/d08.wav
# process AudioData/KL/d09.wav
# process AudioData/KL/d10.wav
# process AudioData/KL/d11.wav
# process AudioData/KL/d12.wav
# process AudioData/KL/d13.wav
# process AudioData/KL/d14.wav
# process AudioData/KL/d15.wav
# process AudioData/KL/f01.wav
# process AudioData/KL/f02.wav
# process AudioData/KL/f03.wav
# process AudioData/KL/f04.wav
# process AudioData/KL/f05.wav
# process AudioData/KL/f06.wav
# process AudioData/KL/f07.wav
# process AudioData/KL/f08.wav
# process AudioData/KL/f09.wav
# process AudioData/KL/f10.wav
# process AudioData/KL/f11.wav
# process AudioData/KL/f12.wav
# process AudioData/KL/f13.wav
# process AudioData/KL/f14.wav
# process AudioData/KL/f15.wav
# process AudioData/KL/h01.wav
# process AudioData/KL/h02.wav
# process AudioData/KL/h03.wav
# process AudioData/KL/h04.wav
# process AudioData/KL/h05.wav
# process AudioData/KL/h06.wav
# process AudioData/KL/h07.wav
# process AudioData/KL/h08.wav
# process AudioData/KL/h09.wav
# process AudioData/KL/h10.wav
# process AudioData/KL/h11.wav
# process AudioData/KL/h12.wav
# process AudioData/KL/h13.wav
# process AudioData/KL/h14.wav
# process AudioData/KL/h15.wav
# process AudioData/KL/n01.wav
# process AudioData/KL/n02.wav
# process AudioData/KL/n03.wav
# process AudioData/KL/n04.wav
# process AudioData/KL/n05.wav
# process AudioData/KL/n06.wav
# process AudioData/KL/n07.wav
# process AudioData/KL/n08.wav
# process AudioData/KL/n09.wav
# process AudioData/KL/n10.wav
# process AudioData/KL/n11.wav
# process AudioData/KL/n12.wav
# process AudioData/KL/n13.wav
# process AudioData/KL/n14.wav
# process AudioData/KL/n15.wav
# process AudioData/KL/n16.wav
# process AudioData/KL/n17.wav
# process AudioData/KL/n18.wav
# process AudioData/KL/n19.wav
# process AudioData/KL/n20.wav
# process AudioData/KL/n21.wav
# process AudioData/KL/n22.wav
# process AudioData/KL/n23.wav
# process AudioData/KL/n24.wav
# process AudioData/KL/n25.wav
# process AudioData/KL/n26.wav
# process AudioData/KL/n27.wav
# process AudioData/KL/n28.wav
# process AudioData/KL/n29.wav
# process AudioData/KL/n30.wav
# process AudioData/KL/sa01.wav
# process AudioData/KL/sa02.wav
# process AudioData/KL/sa03.wav
# process AudioData/KL/sa04.wav
# process AudioData/KL/sa05.wav
# process AudioData/KL/sa06.wav
# process AudioData/KL/sa07.wav
# process AudioData/KL/sa08.wav
# process AudioData/KL/sa09.wav
# process AudioData/KL/sa10.wav
# process AudioData/KL/sa11.wav
# process AudioData/KL/sa12.wav
# process AudioData/KL/sa13.wav
# process AudioData/KL/sa14.wav
# process AudioData/KL/sa15.wav
# process AudioData/KL/su01.wav
# process AudioData/KL/su02.wav
# process AudioData/KL/su03.wav
# process AudioData/KL/su04.wav
# process AudioData/KL/su05.wav
# process AudioData/KL/su06.wav
# process AudioData/KL/su07.wav
# process AudioData/KL/su08.wav
# process AudioData/KL/su09.wav
# process AudioData/KL/su10.wav
# process AudioData/KL/su11.wav
# process AudioData/KL/su12.wav
# process AudioData/KL/su13.wav
# process AudioData/KL/su14.wav
# process AudioData/KL/su15.wav
# process AudioData/DC/a01.wav
# process AudioData/DC/a02.wav
# process AudioData/DC/a03.wav
# process AudioData/DC/a04.wav
# process AudioData/DC/a05.wav
# process AudioData/DC/a06.wav
# process AudioData/DC/a07.wav
# process AudioData/DC/a08.wav
# process AudioData/DC/a09.wav
# process AudioData/DC/a10.wav
# process AudioData/DC/a11.wav
# process AudioData/DC/a12.wav
# process AudioData/DC/a13.wav
# process AudioData/DC/a14.wav
# process AudioData/DC/a15.wav
# process AudioData/DC/d01.wav
# process AudioData/DC/d02.wav
# process AudioData/DC/d03.wav
# process AudioData/DC/d04.wav
# process AudioData/DC/d05.wav
# process AudioData/DC/d06.wav
# process AudioData/DC/d07.wav
# process AudioData/DC/d08.wav
# process AudioData/DC/d09.wav
# process AudioData/DC/d10.wav
# process AudioData/DC/d11.wav
# process AudioData/DC/d12.wav
# process AudioData/DC/d13.wav
# process AudioData/DC/d14.wav
# process AudioData/DC/d15.wav
# process AudioData/DC/f01.wav
# process AudioData/DC/f02.wav
# process AudioData/DC/f03.wav
# process AudioData/DC/f04.wav
# process AudioData/DC/f05.wav
# process AudioData/DC/f06.wav
# process AudioData/DC/f07.wav
# process AudioData/DC/f08.wav
# process AudioData/DC/f09.wav
# process AudioData/DC/f10.wav
# process AudioData/DC/f11.wav
# process AudioData/DC/f12.wav
# process AudioData/DC/f13.wav
# process AudioData/DC/f14.wav
# process AudioData/DC/f15.wav
# process AudioData/DC/h01.wav
# process AudioData/DC/h02.wav
# process AudioData/DC/h03.wav
# process AudioData/DC/h04.wav
# process AudioData/DC/h05.wav
# process AudioData/DC/h06.wav
# process AudioData/DC/h07.wav
# process AudioData/DC/h08.wav
# process AudioData/DC/h09.wav
# process AudioData/DC/h10.wav
# process AudioData/DC/h11.wav
# process AudioData/DC/h12.wav
# process AudioData/DC/h13.wav
# process AudioData/DC/h14.wav
# process AudioData/DC/h15.wav
# process AudioData/DC/n01.wav
# process AudioData/DC/n02.wav
# process AudioData/DC/n03.wav
# process AudioData/DC/n04.wav
# process AudioData/DC/n05.wav
# process AudioData/DC/n06.wav
# process AudioData/DC/n07.wav
# process AudioData/DC/n08.wav
# process AudioData/DC/n09.wav
# process AudioData/DC/n10.wav
# process AudioData/DC/n11.wav
# process AudioData/DC/n12.wav
# process AudioData/DC/n13.wav
# process AudioData/DC/n14.wav
# process AudioData/DC/n15.wav
# process AudioData/DC/n16.wav
# process AudioData/DC/n17.wav
# process AudioData/DC/n18.wav
# process AudioData/DC/n19.wav
# process AudioData/DC/n20.wav
# process AudioData/DC/n21.wav
# process AudioData/DC/n22.wav
# process AudioData/DC/n23.wav
# process AudioData/DC/n24.wav
# process AudioData/DC/n25.wav
# process AudioData/DC/n26.wav
# process AudioData/DC/n27.wav
# process AudioData/DC/n28.wav
# process AudioData/DC/n29.wav
# process AudioData/DC/n30.wav
# process AudioData/DC/sa01.wav
# process AudioData/DC/sa02.wav
# process AudioData/DC/sa03.wav
# process AudioData/DC/sa04.wav
# process AudioData/DC/sa05.wav
# process AudioData/DC/sa06.wav
# process AudioData/DC/sa07.wav
# process AudioData/DC/sa08.wav
# process AudioData/DC/sa09.wav
# process AudioData/DC/sa10.wav
# process AudioData/DC/sa11.wav
# process AudioData/DC/sa12.wav
# process AudioData/DC/sa13.wav
# process AudioData/DC/sa14.wav
# process AudioData/DC/sa15.wav
# process AudioData/DC/su01.wav
# process AudioData/DC/su02.wav
# process AudioData/DC/su03.wav
# process AudioData/DC/su04.wav
# process AudioData/DC/su05.wav
# process AudioData/DC/su06.wav
# process AudioData/DC/su07.wav
# process AudioData/DC/su08.wav
# process AudioData/DC/su09.wav
# process AudioData/DC/su10.wav
# process AudioData/DC/su11.wav
# process AudioData/DC/su12.wav
# process AudioData/DC/su13.wav
# process AudioData/DC/su14.wav
# process AudioData/DC/su15.wav
# process AudioData/JE/a01.wav
# process AudioData/JE/a02.wav
# process AudioData/JE/a03.wav
# process AudioData/JE/a04.wav
# process AudioData/JE/a05.wav
# process AudioData/JE/a06.wav
# process AudioData/JE/a07.wav
# process AudioData/JE/a08.wav
# process AudioData/JE/a09.wav
# process AudioData/JE/a10.wav
# process AudioData/JE/a11.wav
# process AudioData/JE/a12.wav
# process AudioData/JE/a13.wav
# process AudioData/JE/a14.wav
# process AudioData/JE/a15.wav
# process AudioData/JE/d01.wav
# process AudioData/JE/d02.wav
# process AudioData/JE/d03.wav
# process AudioData/JE/d04.wav
# process AudioData/JE/d05.wav
# process AudioData/JE/d06.wav
# process AudioData/JE/d07.wav
# process AudioData/JE/d08.wav
# process AudioData/JE/d09.wav
# process AudioData/JE/d10.wav
# process AudioData/JE/d11.wav
# process AudioData/JE/d12.wav
# process AudioData/JE/d13.wav
# process AudioData/JE/d14.wav
# process AudioData/JE/d15.wav
# process AudioData/JE/f01.wav
# process AudioData/JE/f02.wav
# process AudioData/JE/f03.wav
# process AudioData/JE/f04.wav
# process AudioData/JE/f05.wav
# process AudioData/JE/f06.wav
# process AudioData/JE/f07.wav
# process AudioData/JE/f08.wav
# process AudioData/JE/f09.wav
# process AudioData/JE/f10.wav
# process AudioData/JE/f11.wav
# process AudioData/JE/f12.wav
# process AudioData/JE/f13.wav
# process AudioData/JE/f14.wav
# process AudioData/JE/f15.wav
# process AudioData/JE/h01.wav
# process AudioData/JE/h02.wav
# process AudioData/JE/h03.wav
# process AudioData/JE/h04.wav
# process AudioData/JE/h05.wav
# process AudioData/JE/h06.wav
# process AudioData/JE/h07.wav
# process AudioData/JE/h08.wav
# process AudioData/JE/h09.wav
# process AudioData/JE/h10.wav
# process AudioData/JE/h11.wav
# process AudioData/JE/h12.wav
# process AudioData/JE/h13.wav
# process AudioData/JE/h14.wav
# process AudioData/JE/h15.wav
# process AudioData/JE/n01.wav
# process AudioData/JE/n02.wav
# process AudioData/JE/n03.wav
# process AudioData/JE/n04.wav
# process AudioData/JE/n05.wav
# process AudioData/JE/n06.wav
# process AudioData/JE/n07.wav
# process AudioData/JE/n08.wav
# process AudioData/JE/n09.wav
# process AudioData/JE/n10.wav
# process AudioData/JE/n11.wav
# process AudioData/JE/n12.wav
# process AudioData/JE/n13.wav
# process AudioData/JE/n14.wav
# process AudioData/JE/n15.wav
# process AudioData/JE/n16.wav
# process AudioData/JE/n17.wav
# process AudioData/JE/n18.wav
# process AudioData/JE/n19.wav
# process AudioData/JE/n20.wav
# process AudioData/JE/n21.wav
# process AudioData/JE/n22.wav
# process AudioData/JE/n23.wav
# process AudioData/JE/n24.wav
# process AudioData/JE/n25.wav
# process AudioData/JE/n26.wav
# process AudioData/JE/n27.wav
# process AudioData/JE/n28.wav
# process AudioData/JE/n29.wav
# process AudioData/JE/n30.wav
# process AudioData/JE/sa01.wav
# process AudioData/JE/sa02.wav
# process AudioData/JE/sa03.wav
# process AudioData/JE/sa04.wav
# process AudioData/JE/sa05.wav
# process AudioData/JE/sa06.wav
# process AudioData/JE/sa07.wav
# process AudioData/JE/sa08.wav
# process AudioData/JE/sa09.wav
# process AudioData/JE/sa10.wav
# process AudioData/JE/sa11.wav
# process AudioData/JE/sa12.wav
# process AudioData/JE/sa13.wav
# process AudioData/JE/sa14.wav
# process AudioData/JE/sa15.wav
# process AudioData/JE/su01.wav
# process AudioData/JE/su02.wav
# process AudioData/JE/su03.wav
# process AudioData/JE/su04.wav
# process AudioData/JE/su05.wav
# process AudioData/JE/su06.wav
# process AudioData/JE/su07.wav
# process AudioData/JE/su08.wav
# process AudioData/JE/su09.wav
# process AudioData/JE/su10.wav
# process AudioData/JE/su11.wav
# process AudioData/JE/su12.wav
# process AudioData/JE/su13.wav
# process AudioData/JE/su14.wav
# process AudioData/JE/su15.wav
# process AudioData/JK/a01.wav
# process AudioData/JK/a02.wav
# process AudioData/JK/a03.wav
# process AudioData/JK/a04.wav
# process AudioData/JK/a05.wav
# process AudioData/JK/a06.wav
# process AudioData/JK/a07.wav
# process AudioData/JK/a08.wav
# process AudioData/JK/a09.wav
# process AudioData/JK/a10.wav
# process AudioData/JK/a11.wav
# process AudioData/JK/a12.wav
# process AudioData/JK/a13.wav
# process AudioData/JK/a14.wav
# process AudioData/JK/a15.wav
# process AudioData/JK/d01.wav
# process AudioData/JK/d02.wav
# process AudioData/JK/d03.wav
# process AudioData/JK/d04.wav
# process AudioData/JK/d05.wav
# process AudioData/JK/d06.wav
# process AudioData/JK/d07.wav
# process AudioData/JK/d08.wav
# process AudioData/JK/d09.wav
# process AudioData/JK/d10.wav
# process AudioData/JK/d11.wav
# process AudioData/JK/d12.wav
# process AudioData/JK/d13.wav
# process AudioData/JK/d14.wav
# process AudioData/JK/d15.wav
# process AudioData/JK/f01.wav
# process AudioData/JK/f02.wav
# process AudioData/JK/f03.wav
# process AudioData/JK/f04.wav
# process AudioData/JK/f05.wav
# process AudioData/JK/f06.wav
# process AudioData/JK/f07.wav
# process AudioData/JK/f08.wav
# process AudioData/JK/f09.wav
# process AudioData/JK/f10.wav
# process AudioData/JK/f11.wav
# process AudioData/JK/f12.wav
# process AudioData/JK/f13.wav
# process AudioData/JK/f14.wav
# process AudioData/JK/f15.wav
# process AudioData/JK/h01.wav
# process AudioData/JK/h02.wav
# process AudioData/JK/h03.wav
# process AudioData/JK/h04.wav
# process AudioData/JK/h05.wav
# process AudioData/JK/h06.wav
# process AudioData/JK/h07.wav
# process AudioData/JK/h08.wav
# process AudioData/JK/h09.wav
# process AudioData/JK/h10.wav
# process AudioData/JK/h11.wav
# process AudioData/JK/h12.wav
# process AudioData/JK/h13.wav
# process AudioData/JK/h14.wav
# process AudioData/JK/h15.wav
# process AudioData/JK/n01.wav
# process AudioData/JK/n02.wav
# process AudioData/JK/n03.wav
# process AudioData/JK/n04.wav
# process AudioData/JK/n05.wav
# process AudioData/JK/n06.wav
# process AudioData/JK/n07.wav
# process AudioData/JK/n08.wav
# process AudioData/JK/n09.wav
# process AudioData/JK/n10.wav
# process AudioData/JK/n11.wav
# process AudioData/JK/n12.wav
# process AudioData/JK/n13.wav
# process AudioData/JK/n14.wav
# process AudioData/JK/n15.wav
# process AudioData/JK/n16.wav
# process AudioData/JK/n17.wav
# process AudioData/JK/n18.wav
# process AudioData/JK/n19.wav
# process AudioData/JK/n20.wav
# process AudioData/JK/n21.wav
# process AudioData/JK/n22.wav
# process AudioData/JK/n23.wav
# process AudioData/JK/n24.wav
# process AudioData/JK/n25.wav
# process AudioData/JK/n26.wav
# process AudioData/JK/n27.wav
# process AudioData/JK/n28.wav
# process AudioData/JK/n29.wav
# process AudioData/JK/n30.wav
# process AudioData/JK/sa01.wav
# process AudioData/JK/sa02.wav
# process AudioData/JK/sa03.wav
# process AudioData/JK/sa04.wav
# process AudioData/JK/sa05.wav
# process AudioData/JK/sa06.wav
# process AudioData/JK/sa07.wav
# process AudioData/JK/sa08.wav
# process AudioData/JK/sa09.wav
# process AudioData/JK/sa10.wav
# process AudioData/JK/sa11.wav
# process AudioData/JK/sa12.wav
# process AudioData/JK/sa13.wav
# process AudioData/JK/sa14.wav
# process AudioData/JK/sa15.wav
# process AudioData/JK/su01.wav
# process AudioData/JK/su02.wav
# process AudioData/JK/su03.wav
# process AudioData/JK/su04.wav
# process AudioData/JK/su05.wav
# process AudioData/JK/su06.wav
# process AudioData/JK/su07.wav
# process AudioData/JK/su08.wav
# process AudioData/JK/su09.wav
# process AudioData/JK/su10.wav
# process AudioData/JK/su11.wav
# process AudioData/JK/su12.wav
# process AudioData/JK/su13.wav
# process AudioData/JK/su14.wav
# process AudioData/JK/su15.wav
# process AudioData/KL/a01.wav
# process AudioData/KL/a02.wav
# process AudioData/KL/a03.wav
# process AudioData/KL/a04.wav
# process AudioData/KL/a05.wav
# process AudioData/KL/a06.wav
# process AudioData/KL/a07.wav
# process AudioData/KL/a08.wav
# process AudioData/KL/a09.wav
# process AudioData/KL/a10.wav
# process AudioData/KL/a11.wav
# process AudioData/KL/a12.wav
# process AudioData/KL/a13.wav
# process AudioData/KL/a14.wav
# process AudioData/KL/a15.wav
# process AudioData/KL/d01.wav
# process AudioData/KL/d02.wav
# process AudioData/KL/d03.wav
# process AudioData/KL/d04.wav
# process AudioData/KL/d05.wav
# process AudioData/KL/d06.wav
# process AudioData/KL/d07.wav
# process AudioData/KL/d08.wav
# process AudioData/KL/d09.wav
# process AudioData/KL/d10.wav
# process AudioData/KL/d11.wav
# process AudioData/KL/d12.wav
# process AudioData/KL/d13.wav
# process AudioData/KL/d14.wav
# process AudioData/KL/d15.wav
# process AudioData/KL/f01.wav
# process AudioData/KL/f02.wav
# process AudioData/KL/f03.wav
# process AudioData/KL/f04.wav
# process AudioData/KL/f05.wav
# process AudioData/KL/f06.wav
# process AudioData/KL/f07.wav
# process AudioData/KL/f08.wav
# process AudioData/KL/f09.wav
# process AudioData/KL/f10.wav
# process AudioData/KL/f11.wav
# process AudioData/KL/f12.wav
# process AudioData/KL/f13.wav
# process AudioData/KL/f14.wav
# process AudioData/KL/f15.wav
# process AudioData/KL/h01.wav
# process AudioData/KL/h02.wav
# process AudioData/KL/h03.wav
# process AudioData/KL/h04.wav
# process AudioData/KL/h05.wav
# process AudioData/KL/h06.wav
# process AudioData/KL/h07.wav
# process AudioData/KL/h08.wav
# process AudioData/KL/h09.wav
# process AudioData/KL/h10.wav
# process AudioData/KL/h11.wav
# process AudioData/KL/h12.wav
# process AudioData/KL/h13.wav
# process AudioData/KL/h14.wav
# process AudioData/KL/h15.wav
# process AudioData/KL/n01.wav
# process AudioData/KL/n02.wav
# process AudioData/KL/n03.wav
# process AudioData/KL/n04.wav
# process AudioData/KL/n05.wav
# process AudioData/KL/n06.wav
# process AudioData/KL/n07.wav
# process AudioData/KL/n08.wav
# process AudioData/KL/n09.wav
# process AudioData/KL/n10.wav
# process AudioData/KL/n11.wav
# process AudioData/KL/n12.wav
# process AudioData/KL/n13.wav
# process AudioData/KL/n14.wav
# process AudioData/KL/n15.wav
# process AudioData/KL/n16.wav
# process AudioData/KL/n17.wav
# process AudioData/KL/n18.wav
# process AudioData/KL/n19.wav
# process AudioData/KL/n20.wav
# process AudioData/KL/n21.wav
# process AudioData/KL/n22.wav
# process AudioData/KL/n23.wav
# process AudioData/KL/n24.wav
# process AudioData/KL/n25.wav
# process AudioData/KL/n26.wav
# process AudioData/KL/n27.wav
# process AudioData/KL/n28.wav
# process AudioData/KL/n29.wav
# process AudioData/KL/n30.wav
# process AudioData/KL/sa01.wav
# process AudioData/KL/sa02.wav
# process AudioData/KL/sa03.wav
# process AudioData/KL/sa04.wav
# process AudioData/KL/sa05.wav
# process AudioData/KL/sa06.wav
# process AudioData/KL/sa07.wav
# process AudioData/KL/sa08.wav
# process AudioData/KL/sa09.wav
# process AudioData/KL/sa10.wav
# process AudioData/KL/sa11.wav
# process AudioData/KL/sa12.wav
# process AudioData/KL/sa13.wav
# process AudioData/KL/sa14.wav
# process AudioData/KL/sa15.wav
# process AudioData/KL/su01.wav
# process AudioData/KL/su02.wav
# process AudioData/KL/su03.wav
# process AudioData/KL/su04.wav
# process AudioData/KL/su05.wav
# process AudioData/KL/su06.wav
# process AudioData/KL/su07.wav
# process AudioData/KL/su08.wav
# process AudioData/KL/su09.wav
# process AudioData/KL/su10.wav
# process AudioData/KL/su11.wav
# process AudioData/KL/su12.wav
# process AudioData/KL/su13.wav
# process AudioData/KL/su14.wav
# process AudioData/KL/su15.wav
# process AudioData/DC/a01.wav
# process AudioData/DC/a02.wav
# process AudioData/DC/a03.wav
# process AudioData/DC/a04.wav
# process AudioData/DC/a05.wav
# process AudioData/DC/a06.wav
# process AudioData/DC/a07.wav
# process AudioData/DC/a08.wav
# process AudioData/DC/a09.wav
# process AudioData/DC/a10.wav
# process AudioData/DC/a11.wav
# process AudioData/DC/a12.wav
# process AudioData/DC/a13.wav
# process AudioData/DC/a14.wav
# process AudioData/DC/a15.wav
# process AudioData/DC/d01.wav
# process AudioData/DC/d02.wav
# process AudioData/DC/d03.wav
# process AudioData/DC/d04.wav
# process AudioData/DC/d05.wav
# process AudioData/DC/d06.wav
# process AudioData/DC/d07.wav
# process AudioData/DC/d08.wav
# process AudioData/DC/d09.wav
# process AudioData/DC/d10.wav
# process AudioData/DC/d11.wav
# process AudioData/DC/d12.wav
# process AudioData/DC/d13.wav
# process AudioData/DC/d14.wav
# process AudioData/DC/d15.wav
# process AudioData/DC/f01.wav
# process AudioData/DC/f02.wav
# process AudioData/DC/f03.wav
# process AudioData/DC/f04.wav
# process AudioData/DC/f05.wav
# process AudioData/DC/f06.wav
# process AudioData/DC/f07.wav
# process AudioData/DC/f08.wav
# process AudioData/DC/f09.wav
# process AudioData/DC/f10.wav
# process AudioData/DC/f11.wav
# process AudioData/DC/f12.wav
# process AudioData/DC/f13.wav
# process AudioData/DC/f14.wav
# process AudioData/DC/f15.wav
# process AudioData/DC/h01.wav
# process AudioData/DC/h02.wav
# process AudioData/DC/h03.wav
# process AudioData/DC/h04.wav
# process AudioData/DC/h05.wav
# process AudioData/DC/h06.wav
# process AudioData/DC/h07.wav
# process AudioData/DC/h08.wav
# process AudioData/DC/h09.wav
# process AudioData/DC/h10.wav
# process AudioData/DC/h11.wav
# process AudioData/DC/h12.wav
# process AudioData/DC/h13.wav
# process AudioData/DC/h14.wav
# process AudioData/DC/h15.wav
# process AudioData/DC/n01.wav
# process AudioData/DC/n02.wav
# process AudioData/DC/n03.wav
# process AudioData/DC/n04.wav
# process AudioData/DC/n05.wav
# process AudioData/DC/n06.wav
# process AudioData/DC/n07.wav
# process AudioData/DC/n08.wav
# process AudioData/DC/n09.wav
# process AudioData/DC/n10.wav
# process AudioData/DC/n11.wav
# process AudioData/DC/n12.wav
# process AudioData/DC/n13.wav
# process AudioData/DC/n14.wav
# process AudioData/DC/n15.wav
# process AudioData/DC/n16.wav
# process AudioData/DC/n17.wav
# process AudioData/DC/n18.wav
# process AudioData/DC/n19.wav
# process AudioData/DC/n20.wav
# process AudioData/DC/n21.wav
# process AudioData/DC/n22.wav
# process AudioData/DC/n23.wav
# process AudioData/DC/n24.wav
# process AudioData/DC/n25.wav
# process AudioData/DC/n26.wav
# process AudioData/DC/n27.wav
# process AudioData/DC/n28.wav
# process AudioData/DC/n29.wav
# process AudioData/DC/n30.wav
# process AudioData/DC/sa01.wav
# process AudioData/DC/sa02.wav
# process AudioData/DC/sa03.wav
# process AudioData/DC/sa04.wav
# process AudioData/DC/sa05.wav
# process AudioData/DC/sa06.wav
# process AudioData/DC/sa07.wav
# process AudioData/DC/sa08.wav
# process AudioData/DC/sa09.wav
# process AudioData/DC/sa10.wav
# process AudioData/DC/sa11.wav
# process AudioData/DC/sa12.wav
# process AudioData/DC/sa13.wav
# process AudioData/DC/sa14.wav
# process AudioData/DC/sa15.wav
# process AudioData/DC/su01.wav
# process AudioData/DC/su02.wav
# process AudioData/DC/su03.wav
# process AudioData/DC/su04.wav
# process AudioData/DC/su05.wav
# process AudioData/DC/su06.wav
# process AudioData/DC/su07.wav
# process AudioData/DC/su08.wav
# process AudioData/DC/su09.wav
# process AudioData/DC/su10.wav
# process AudioData/DC/su11.wav
# process AudioData/DC/su12.wav
# process AudioData/DC/su13.wav
# process AudioData/DC/su14.wav
# process AudioData/DC/su15.wav
# process AudioData/JE/a01.wav
# process AudioData/JE/a02.wav
# process AudioData/JE/a03.wav
# process AudioData/JE/a04.wav
# process AudioData/JE/a05.wav
# process AudioData/JE/a06.wav
# process AudioData/JE/a07.wav
# process AudioData/JE/a08.wav
# process AudioData/JE/a09.wav
# process AudioData/JE/a10.wav
# process AudioData/JE/a11.wav
# process AudioData/JE/a12.wav
# process AudioData/JE/a13.wav
# process AudioData/JE/a14.wav
# process AudioData/JE/a15.wav
# process AudioData/JE/d01.wav
# process AudioData/JE/d02.wav
# process AudioData/JE/d03.wav
# process AudioData/JE/d04.wav
# process AudioData/JE/d05.wav
# process AudioData/JE/d06.wav
# process AudioData/JE/d07.wav
# process AudioData/JE/d08.wav
# process AudioData/JE/d09.wav
# process AudioData/JE/d10.wav
# process AudioData/JE/d11.wav
# process AudioData/JE/d12.wav
# process AudioData/JE/d13.wav
# process AudioData/JE/d14.wav
# process AudioData/JE/d15.wav
# process AudioData/JE/f01.wav
# process AudioData/JE/f02.wav
# process AudioData/JE/f03.wav
# process AudioData/JE/f04.wav
# process AudioData/JE/f05.wav
# process AudioData/JE/f06.wav
# process AudioData/JE/f07.wav
# process AudioData/JE/f08.wav
# process AudioData/JE/f09.wav
# process AudioData/JE/f10.wav
# process AudioData/JE/f11.wav
# process AudioData/JE/f12.wav
# process AudioData/JE/f13.wav
# process AudioData/JE/f14.wav
# process AudioData/JE/f15.wav
# process AudioData/JE/h01.wav
# process AudioData/JE/h02.wav
# process AudioData/JE/h03.wav
# process AudioData/JE/h04.wav
# process AudioData/JE/h05.wav
# process AudioData/JE/h06.wav
# process AudioData/JE/h07.wav
# process AudioData/JE/h08.wav
# process AudioData/JE/h09.wav
# process AudioData/JE/h10.wav
# process AudioData/JE/h11.wav
# process AudioData/JE/h12.wav
# process AudioData/JE/h13.wav
# process AudioData/JE/h14.wav
# process AudioData/JE/h15.wav
# process AudioData/JE/n01.wav
# process AudioData/JE/n02.wav
# process AudioData/JE/n03.wav
# process AudioData/JE/n04.wav
# process AudioData/JE/n05.wav
# process AudioData/JE/n06.wav
# process AudioData/JE/n07.wav
# process AudioData/JE/n08.wav
# process AudioData/JE/n09.wav
# process AudioData/JE/n10.wav
# process AudioData/JE/n11.wav
# process AudioData/JE/n12.wav
# process AudioData/JE/n13.wav
# process AudioData/JE/n14.wav
# process AudioData/JE/n15.wav
# process AudioData/JE/n16.wav
# process AudioData/JE/n17.wav
# process AudioData/JE/n18.wav
# process AudioData/JE/n19.wav
# process AudioData/JE/n20.wav
# process AudioData/JE/n21.wav
# process AudioData/JE/n22.wav
# process AudioData/JE/n23.wav
# process AudioData/JE/n24.wav
# process AudioData/JE/n25.wav
# process AudioData/JE/n26.wav
# process AudioData/JE/n27.wav
# process AudioData/JE/n28.wav
# process AudioData/JE/n29.wav
# process AudioData/JE/n30.wav
# process AudioData/JE/sa01.wav
# process AudioData/JE/sa02.wav
# process AudioData/JE/sa03.wav
# process AudioData/JE/sa04.wav
# process AudioData/JE/sa05.wav
# process AudioData/JE/sa06.wav
# process AudioData/JE/sa07.wav
# process AudioData/JE/sa08.wav
# process AudioData/JE/sa09.wav
# process AudioData/JE/sa10.wav
# process AudioData/JE/sa11.wav
# process AudioData/JE/sa12.wav
# process AudioData/JE/sa13.wav
# process AudioData/JE/sa14.wav
# process AudioData/JE/sa15.wav
# process AudioData/JE/su01.wav
# process AudioData/JE/su02.wav
# process AudioData/JE/su03.wav
# process AudioData/JE/su04.wav
# process AudioData/JE/su05.wav
# process AudioData/JE/su06.wav
# process AudioData/JE/su07.wav
# process AudioData/JE/su08.wav
# process AudioData/JE/su09.wav
# process AudioData/JE/su10.wav
# process AudioData/JE/su11.wav
# process AudioData/JE/su12.wav
# process AudioData/JE/su13.wav
# process AudioData/JE/su14.wav
# process AudioData/JE/su15.wav
# process AudioData/JK/a01.wav
# process AudioData/JK/a02.wav
# process AudioData/JK/a03.wav
# process AudioData/JK/a04.wav
# process AudioData/JK/a05.wav
# process AudioData/JK/a06.wav
# process AudioData/JK/a07.wav
# process AudioData/JK/a08.wav
# process AudioData/JK/a09.wav
# process AudioData/JK/a10.wav
# process AudioData/JK/a11.wav
# process AudioData/JK/a12.wav
# process AudioData/JK/a13.wav
# process AudioData/JK/a14.wav
# process AudioData/JK/a15.wav
# process AudioData/JK/d01.wav
# process AudioData/JK/d02.wav
# process AudioData/JK/d03.wav
# process AudioData/JK/d04.wav
# process AudioData/JK/d05.wav
# process AudioData/JK/d06.wav
# process AudioData/JK/d07.wav
# process AudioData/JK/d08.wav
# process AudioData/JK/d09.wav
# process AudioData/JK/d10.wav
# process AudioData/JK/d11.wav
# process AudioData/JK/d12.wav
# process AudioData/JK/d13.wav
# process AudioData/JK/d14.wav
# process AudioData/JK/d15.wav
# process AudioData/JK/f01.wav
# process AudioData/JK/f02.wav
# process AudioData/JK/f03.wav
# process AudioData/JK/f04.wav
# process AudioData/JK/f05.wav
# process AudioData/JK/f06.wav
# process AudioData/JK/f07.wav
# process AudioData/JK/f08.wav
# process AudioData/JK/f09.wav
# process AudioData/JK/f10.wav
# process AudioData/JK/f11.wav
# process AudioData/JK/f12.wav
# process AudioData/JK/f13.wav
# process AudioData/JK/f14.wav
# process AudioData/JK/f15.wav
# process AudioData/JK/h01.wav
# process AudioData/JK/h02.wav
# process AudioData/JK/h03.wav
# process AudioData/JK/h04.wav
# process AudioData/JK/h05.wav
# process AudioData/JK/h06.wav
# process AudioData/JK/h07.wav
# process AudioData/JK/h08.wav
# process AudioData/JK/h09.wav
# process AudioData/JK/h10.wav
# process AudioData/JK/h11.wav
# process AudioData/JK/h12.wav
# process AudioData/JK/h13.wav
# process AudioData/JK/h14.wav
# process AudioData/JK/h15.wav
# process AudioData/JK/n01.wav
# process AudioData/JK/n02.wav
# process AudioData/JK/n03.wav
# process AudioData/JK/n04.wav
# process AudioData/JK/n05.wav
# process AudioData/JK/n06.wav
# process AudioData/JK/n07.wav
# process AudioData/JK/n08.wav
# process AudioData/JK/n09.wav
# process AudioData/JK/n10.wav
# process AudioData/JK/n11.wav
# process AudioData/JK/n12.wav
# process AudioData/JK/n13.wav
# process AudioData/JK/n14.wav
# process AudioData/JK/n15.wav
# process AudioData/JK/n16.wav
# process AudioData/JK/n17.wav
# process AudioData/JK/n18.wav
# process AudioData/JK/n19.wav
# process AudioData/JK/n20.wav
# process AudioData/JK/n21.wav
# process AudioData/JK/n22.wav
# process AudioData/JK/n23.wav
# process AudioData/JK/n24.wav
# process AudioData/JK/n25.wav
# process AudioData/JK/n26.wav
# process AudioData/JK/n27.wav
# process AudioData/JK/n28.wav
# process AudioData/JK/n29.wav
# process AudioData/JK/n30.wav
# process AudioData/JK/sa01.wav
# process AudioData/JK/sa02.wav
# process AudioData/JK/sa03.wav
# process AudioData/JK/sa04.wav
# process AudioData/JK/sa05.wav
# process AudioData/JK/sa06.wav
# process AudioData/JK/sa07.wav
# process AudioData/JK/sa08.wav
# process AudioData/JK/sa09.wav
# process AudioData/JK/sa10.wav
# process AudioData/JK/sa11.wav
# process AudioData/JK/sa12.wav
# process AudioData/JK/sa13.wav
# process AudioData/JK/sa14.wav
# process AudioData/JK/sa15.wav
# process AudioData/JK/su01.wav
# process AudioData/JK/su02.wav
# process AudioData/JK/su03.wav
# process AudioData/JK/su04.wav
# process AudioData/JK/su05.wav
# process AudioData/JK/su06.wav
# process AudioData/JK/su07.wav
# process AudioData/JK/su08.wav
# process AudioData/JK/su09.wav
# process AudioData/JK/su10.wav
# process AudioData/JK/su11.wav
# process AudioData/JK/su12.wav
# process AudioData/JK/su13.wav
# process AudioData/JK/su14.wav
# process AudioData/JK/su15.wav
# process AudioData/KL/a01.wav
# process AudioData/KL/a02.wav
# process AudioData/KL/a03.wav
# process AudioData/KL/a04.wav
# process AudioData/KL/a05.wav
# process AudioData/KL/a06.wav
# process AudioData/KL/a07.wav
# process AudioData/KL/a08.wav
# process AudioData/KL/a09.wav
# process AudioData/KL/a10.wav
# process AudioData/KL/a11.wav
# process AudioData/KL/a12.wav
# process AudioData/KL/a13.wav
# process AudioData/KL/a14.wav
# process AudioData/KL/a15.wav
# process AudioData/KL/d01.wav
# process AudioData/KL/d02.wav
# process AudioData/KL/d03.wav
# process AudioData/KL/d04.wav
# process AudioData/KL/d05.wav
# process AudioData/KL/d06.wav
# process AudioData/KL/d07.wav
# process AudioData/KL/d08.wav
# process AudioData/KL/d09.wav
# process AudioData/KL/d10.wav
# process AudioData/KL/d11.wav
# process AudioData/KL/d12.wav
# process AudioData/KL/d13.wav
# process AudioData/KL/d14.wav
# process AudioData/KL/d15.wav
# process AudioData/KL/f01.wav
# process AudioData/KL/f02.wav
# process AudioData/KL/f03.wav
# process AudioData/KL/f04.wav
# process AudioData/KL/f05.wav
# process AudioData/KL/f06.wav
# process AudioData/KL/f07.wav
# process AudioData/KL/f08.wav
# process AudioData/KL/f09.wav
# process AudioData/KL/f10.wav
# process AudioData/KL/f11.wav
# process AudioData/KL/f12.wav
# process AudioData/KL/f13.wav
# process AudioData/KL/f14.wav
# process AudioData/KL/f15.wav
# process AudioData/KL/h01.wav
# process AudioData/KL/h02.wav
# process AudioData/KL/h03.wav
# process AudioData/KL/h04.wav
# process AudioData/KL/h05.wav
# process AudioData/KL/h06.wav
# process AudioData/KL/h07.wav
# process AudioData/KL/h08.wav
# process AudioData/KL/h09.wav
# process AudioData/KL/h10.wav
# process AudioData/KL/h11.wav
# process AudioData/KL/h12.wav
# process AudioData/KL/h13.wav
# process AudioData/KL/h14.wav
# process AudioData/KL/h15.wav
# process AudioData/KL/n01.wav
# process AudioData/KL/n02.wav
# process AudioData/KL/n03.wav
# process AudioData/KL/n04.wav
# process AudioData/KL/n05.wav
# process AudioData/KL/n06.wav
# process AudioData/KL/n07.wav
# process AudioData/KL/n08.wav
# process AudioData/KL/n09.wav
# process AudioData/KL/n10.wav
# process AudioData/KL/n11.wav
# process AudioData/KL/n12.wav
# process AudioData/KL/n13.wav
# process AudioData/KL/n14.wav
# process AudioData/KL/n15.wav
# process AudioData/KL/n16.wav
# process AudioData/KL/n17.wav
# process AudioData/KL/n18.wav
# process AudioData/KL/n19.wav
# process AudioData/KL/n20.wav
# process AudioData/KL/n21.wav
# process AudioData/KL/n22.wav
# process AudioData/KL/n23.wav
# process AudioData/KL/n24.wav
# process AudioData/KL/n25.wav
# process AudioData/KL/n26.wav
# process AudioData/KL/n27.wav
# process AudioData/KL/n28.wav
# process AudioData/KL/n29.wav
# process AudioData/KL/n30.wav
# process AudioData/KL/sa01.wav
# process AudioData/KL/sa02.wav
# process AudioData/KL/sa03.wav
# process AudioData/KL/sa04.wav
# process AudioData/KL/sa05.wav
# process AudioData/KL/sa06.wav
# process AudioData/KL/sa07.wav
# process AudioData/KL/sa08.wav
# process AudioData/KL/sa09.wav
# process AudioData/KL/sa10.wav
# process AudioData/KL/sa11.wav
# process AudioData/KL/sa12.wav
# process AudioData/KL/sa13.wav
# process AudioData/KL/sa14.wav
# process AudioData/KL/sa15.wav
# process AudioData/KL/su01.wav
# process AudioData/KL/su02.wav
# process AudioData/KL/su03.wav
# process AudioData/KL/su04.wav
# process AudioData/KL/su05.wav
# process AudioData/KL/su06.wav
# process AudioData/KL/su07.wav
# process AudioData/KL/su08.wav
# process AudioData/KL/su09.wav
# process AudioData/KL/su10.wav
# process AudioData/KL/su11.wav
# process AudioData/KL/su12.wav
# process AudioData/KL/su13.wav
# process AudioData/KL/su14.wav
# process AudioData/KL/su15.wav
# process AudioData/DC/a01.wav
# process AudioData/DC/a02.wav
# process AudioData/DC/a03.wav
# process AudioData/DC/a04.wav
# process AudioData/DC/a05.wav
# process AudioData/DC/a06.wav
# process AudioData/DC/a07.wav
# process AudioData/DC/a08.wav
# process AudioData/DC/a09.wav
# process AudioData/DC/a10.wav
# process AudioData/DC/a11.wav
# process AudioData/DC/a12.wav
# process AudioData/DC/a13.wav
# process AudioData/DC/a14.wav
# process AudioData/DC/a15.wav
# process AudioData/DC/d01.wav
# process AudioData/DC/d02.wav
# process AudioData/DC/d03.wav
# process AudioData/DC/d04.wav
# process AudioData/DC/d05.wav
# process AudioData/DC/d06.wav
# process AudioData/DC/d07.wav
# process AudioData/DC/d08.wav
# process AudioData/DC/d09.wav
# process AudioData/DC/d10.wav
# process AudioData/DC/d11.wav
# process AudioData/DC/d12.wav
# process AudioData/DC/d13.wav
# process AudioData/DC/d14.wav
# process AudioData/DC/d15.wav
# process AudioData/DC/f01.wav
# process AudioData/DC/f02.wav
# process AudioData/DC/f03.wav
# process AudioData/DC/f04.wav
# process AudioData/DC/f05.wav
# process AudioData/DC/f06.wav
# process AudioData/DC/f07.wav
# process AudioData/DC/f08.wav
# process AudioData/DC/f09.wav
# process AudioData/DC/f10.wav
# process AudioData/DC/f11.wav
# process AudioData/DC/f12.wav
# process AudioData/DC/f13.wav
# process AudioData/DC/f14.wav
# process AudioData/DC/f15.wav
# process AudioData/DC/h01.wav
# process AudioData/DC/h02.wav
# process AudioData/DC/h03.wav
# process AudioData/DC/h04.wav
# process AudioData/DC/h05.wav
# process AudioData/DC/h06.wav
# process AudioData/DC/h07.wav
# process AudioData/DC/h08.wav
# process AudioData/DC/h09.wav
# process AudioData/DC/h10.wav
# process AudioData/DC/h11.wav
# process AudioData/DC/h12.wav
# process AudioData/DC/h13.wav
# process AudioData/DC/h14.wav
# process AudioData/DC/h15.wav
# process AudioData/DC/n01.wav
# process AudioData/DC/n02.wav
# process AudioData/DC/n03.wav
# process AudioData/DC/n04.wav
# process AudioData/DC/n05.wav
# process AudioData/DC/n06.wav
# process AudioData/DC/n07.wav
# process AudioData/DC/n08.wav
# process AudioData/DC/n09.wav
# process AudioData/DC/n10.wav
# process AudioData/DC/n11.wav
# process AudioData/DC/n12.wav
# process AudioData/DC/n13.wav
# process AudioData/DC/n14.wav
# process AudioData/DC/n15.wav
# process AudioData/DC/n16.wav
# process AudioData/DC/n17.wav
# process AudioData/DC/n18.wav
# process AudioData/DC/n19.wav
# process AudioData/DC/n20.wav
# process AudioData/DC/n21.wav
# process AudioData/DC/n22.wav
# process AudioData/DC/n23.wav
# process AudioData/DC/n24.wav
# process AudioData/DC/n25.wav
# process AudioData/DC/n26.wav
# process AudioData/DC/n27.wav
# process AudioData/DC/n28.wav
# process AudioData/DC/n29.wav
# process AudioData/DC/n30.wav
# process AudioData/DC/sa01.wav
# process AudioData/DC/sa02.wav
# process AudioData/DC/sa03.wav
# process AudioData/DC/sa04.wav
# process AudioData/DC/sa05.wav
# process AudioData/DC/sa06.wav
# process AudioData/DC/sa07.wav
# process AudioData/DC/sa08.wav
# process AudioData/DC/sa09.wav
# process AudioData/DC/sa10.wav
# process AudioData/DC/sa11.wav
# process AudioData/DC/sa12.wav
# process AudioData/DC/sa13.wav
# process AudioData/DC/sa14.wav
# process AudioData/DC/sa15.wav
# process AudioData/DC/su01.wav
# process AudioData/DC/su02.wav
# process AudioData/DC/su03.wav
# process AudioData/DC/su04.wav
# process AudioData/DC/su05.wav
# process AudioData/DC/su06.wav
# process AudioData/DC/su07.wav
# process AudioData/DC/su08.wav
# process AudioData/DC/su09.wav
# process AudioData/DC/su10.wav
# process AudioData/DC/su11.wav
# process AudioData/DC/su12.wav
# process AudioData/DC/su13.wav
# process AudioData/DC/su14.wav
# process AudioData/DC/su15.wav
# process AudioData/JE/a01.wav
# process AudioData/JE/a02.wav
# process AudioData/JE/a03.wav
# process AudioData/JE/a04.wav
# process AudioData/JE/a05.wav
# process AudioData/JE/a06.wav
# process AudioData/JE/a07.wav
# process AudioData/JE/a08.wav
# process AudioData/JE/a09.wav
# process AudioData/JE/a10.wav
# process AudioData/JE/a11.wav
# process AudioData/JE/a12.wav
# process AudioData/JE/a13.wav
# process AudioData/JE/a14.wav
# process AudioData/JE/a15.wav
# process AudioData/JE/d01.wav
# process AudioData/JE/d02.wav
# process AudioData/JE/d03.wav
# process AudioData/JE/d04.wav
# process AudioData/JE/d05.wav
# process AudioData/JE/d06.wav
# process AudioData/JE/d07.wav
# process AudioData/JE/d08.wav
# process AudioData/JE/d09.wav
# process AudioData/JE/d10.wav
# process AudioData/JE/d11.wav
# process AudioData/JE/d12.wav
# process AudioData/JE/d13.wav
# process AudioData/JE/d14.wav
# process AudioData/JE/d15.wav
# process AudioData/JE/f01.wav
# process AudioData/JE/f02.wav
# process AudioData/JE/f03.wav
# process AudioData/JE/f04.wav
# process AudioData/JE/f05.wav
# process AudioData/JE/f06.wav
# process AudioData/JE/f07.wav
# process AudioData/JE/f08.wav
# process AudioData/JE/f09.wav
# process AudioData/JE/f10.wav
# process AudioData/JE/f11.wav
# process AudioData/JE/f12.wav
# process AudioData/JE/f13.wav
# process AudioData/JE/f14.wav
# process AudioData/JE/f15.wav
# process AudioData/JE/h01.wav
# process AudioData/JE/h02.wav
# process AudioData/JE/h03.wav
# process AudioData/JE/h04.wav
# process AudioData/JE/h05.wav
# process AudioData/JE/h06.wav
# process AudioData/JE/h07.wav
# process AudioData/JE/h08.wav
# process AudioData/JE/h09.wav
# process AudioData/JE/h10.wav
# process AudioData/JE/h11.wav
# process AudioData/JE/h12.wav
# process AudioData/JE/h13.wav
# process AudioData/JE/h14.wav
# process AudioData/JE/h15.wav
# process AudioData/JE/n01.wav
# process AudioData/JE/n02.wav
# process AudioData/JE/n03.wav
# process AudioData/JE/n04.wav
# process AudioData/JE/n05.wav
# process AudioData/JE/n06.wav
# process AudioData/JE/n07.wav
# process AudioData/JE/n08.wav
# process AudioData/JE/n09.wav
# process AudioData/JE/n10.wav
# process AudioData/JE/n11.wav
# process AudioData/JE/n12.wav
# process AudioData/JE/n13.wav
# process AudioData/JE/n14.wav
# process AudioData/JE/n15.wav
# process AudioData/JE/n16.wav
# process AudioData/JE/n17.wav
# process AudioData/JE/n18.wav
# process AudioData/JE/n19.wav
# process AudioData/JE/n20.wav
# process AudioData/JE/n21.wav
# process AudioData/JE/n22.wav
# process AudioData/JE/n23.wav
# process AudioData/JE/n24.wav
# process AudioData/JE/n25.wav
# process AudioData/JE/n26.wav
# process AudioData/JE/n27.wav
# process AudioData/JE/n28.wav
# process AudioData/JE/n29.wav
# process AudioData/JE/n30.wav
# process AudioData/JE/sa01.wav
# process AudioData/JE/sa02.wav
# process AudioData/JE/sa03.wav
# process AudioData/JE/sa04.wav
# process AudioData/JE/sa05.wav
# process AudioData/JE/sa06.wav
# process AudioData/JE/sa07.wav
# process AudioData/JE/sa08.wav
# process AudioData/JE/sa09.wav
# process AudioData/JE/sa10.wav
# process AudioData/JE/sa11.wav
# process AudioData/JE/sa12.wav
# process AudioData/JE/sa13.wav
# process AudioData/JE/sa14.wav
# process AudioData/JE/sa15.wav
# process AudioData/JE/su01.wav
# process AudioData/JE/su02.wav
# process AudioData/JE/su03.wav
# process AudioData/JE/su04.wav
# process AudioData/JE/su05.wav
# process AudioData/JE/su06.wav
# process AudioData/JE/su07.wav
# process AudioData/JE/su08.wav
# process AudioData/JE/su09.wav
# process AudioData/JE/su10.wav
# process AudioData/JE/su11.wav
# process AudioData/JE/su12.wav
# process AudioData/JE/su13.wav
# process AudioData/JE/su14.wav
# process AudioData/JE/su15.wav
# process AudioData/JK/a01.wav
# process AudioData/JK/a02.wav
# process AudioData/JK/a03.wav
# process AudioData/JK/a04.wav
# process AudioData/JK/a05.wav
# process AudioData/JK/a06.wav
# process AudioData/JK/a07.wav
# process AudioData/JK/a08.wav
# process AudioData/JK/a09.wav
# process AudioData/JK/a10.wav
# process AudioData/JK/a11.wav
# process AudioData/JK/a12.wav
# process AudioData/JK/a13.wav
# process AudioData/JK/a14.wav
# process AudioData/JK/a15.wav
# process AudioData/JK/d01.wav
# process AudioData/JK/d02.wav
# process AudioData/JK/d03.wav
# process AudioData/JK/d04.wav
# process AudioData/JK/d05.wav
# process AudioData/JK/d06.wav
# process AudioData/JK/d07.wav
# process AudioData/JK/d08.wav
# process AudioData/JK/d09.wav
# process AudioData/JK/d10.wav
# process AudioData/JK/d11.wav
# process AudioData/JK/d12.wav
# process AudioData/JK/d13.wav
# process AudioData/JK/d14.wav
# process AudioData/JK/d15.wav
# process AudioData/JK/f01.wav
# process AudioData/JK/f02.wav
# process AudioData/JK/f03.wav
# process AudioData/JK/f04.wav
# process AudioData/JK/f05.wav
# process AudioData/JK/f06.wav
# process AudioData/JK/f07.wav
# process AudioData/JK/f08.wav
# process AudioData/JK/f09.wav
# process AudioData/JK/f10.wav
# process AudioData/JK/f11.wav
# process AudioData/JK/f12.wav
# process AudioData/JK/f13.wav
# process AudioData/JK/f14.wav
# process AudioData/JK/f15.wav
# process AudioData/JK/h01.wav
# process AudioData/JK/h02.wav
# process AudioData/JK/h03.wav
# process AudioData/JK/h04.wav
# process AudioData/JK/h05.wav
# process AudioData/JK/h06.wav
# process AudioData/JK/h07.wav
# process AudioData/JK/h08.wav
# process AudioData/JK/h09.wav
# process AudioData/JK/h10.wav
# process AudioData/JK/h11.wav
# process AudioData/JK/h12.wav
# process AudioData/JK/h13.wav
# process AudioData/JK/h14.wav
# process AudioData/JK/h15.wav
# process AudioData/JK/n01.wav
# process AudioData/JK/n02.wav
# process AudioData/JK/n03.wav
# process AudioData/JK/n04.wav
# process AudioData/JK/n05.wav
# process AudioData/JK/n06.wav
# process AudioData/JK/n07.wav
# process AudioData/JK/n08.wav
# process AudioData/JK/n09.wav
# process AudioData/JK/n10.wav
# process AudioData/JK/n11.wav
# process AudioData/JK/n12.wav
# process AudioData/JK/n13.wav
# process AudioData/JK/n14.wav
# process AudioData/JK/n15.wav
# process AudioData/JK/n16.wav
# process AudioData/JK/n17.wav
# process AudioData/JK/n18.wav
# process AudioData/JK/n19.wav
# process AudioData/JK/n20.wav
# process AudioData/JK/n21.wav
# process AudioData/JK/n22.wav
# process AudioData/JK/n23.wav
# process AudioData/JK/n24.wav
# process AudioData/JK/n25.wav
# process AudioData/JK/n26.wav
# process AudioData/JK/n27.wav
# process AudioData/JK/n28.wav
# process AudioData/JK/n29.wav
# process AudioData/JK/n30.wav
# process AudioData/JK/sa01.wav
# process AudioData/JK/sa02.wav
# process AudioData/JK/sa03.wav
# process AudioData/JK/sa04.wav
# process AudioData/JK/sa05.wav
# process AudioData/JK/sa06.wav
# process AudioData/JK/sa07.wav
# process AudioData/JK/sa08.wav
# process AudioData/JK/sa09.wav
# process AudioData/JK/sa10.wav
# process AudioData/JK/sa11.wav
# process AudioData/JK/sa12.wav
# process AudioData/JK/sa13.wav
# process AudioData/JK/sa14.wav
# process AudioData/JK/sa15.wav
# process AudioData/JK/su01.wav
# process AudioData/JK/su02.wav
# process AudioData/JK/su03.wav
# process AudioData/JK/su04.wav
# process AudioData/JK/su05.wav
# process AudioData/JK/su06.wav
# process AudioData/JK/su07.wav
# process AudioData/JK/su08.wav
# process AudioData/JK/su09.wav
# process AudioData/JK/su10.wav
# process AudioData/JK/su11.wav
# process AudioData/JK/su12.wav
# process AudioData/JK/su13.wav
# process AudioData/JK/su14.wav
# process AudioData/JK/su15.wav
# process AudioData/KL/a01.wav
# process AudioData/KL/a02.wav
# process AudioData/KL/a03.wav
# process AudioData/KL/a04.wav
# process AudioData/KL/a05.wav
# process AudioData/KL/a06.wav
# process AudioData/KL/a07.wav
# process AudioData/KL/a08.wav
# process AudioData/KL/a09.wav
# process AudioData/KL/a10.wav
# process AudioData/KL/a11.wav
# process AudioData/KL/a12.wav
# process AudioData/KL/a13.wav
# process AudioData/KL/a14.wav
# process AudioData/KL/a15.wav
# process AudioData/KL/d01.wav
# process AudioData/KL/d02.wav
# process AudioData/KL/d03.wav
# process AudioData/KL/d04.wav
# process AudioData/KL/d05.wav
# process AudioData/KL/d06.wav
# process AudioData/KL/d07.wav
# process AudioData/KL/d08.wav
# process AudioData/KL/d09.wav
# process AudioData/KL/d10.wav
# process AudioData/KL/d11.wav
# process AudioData/KL/d12.wav
# process AudioData/KL/d13.wav
# process AudioData/KL/d14.wav
# process AudioData/KL/d15.wav
# process AudioData/KL/f01.wav
# process AudioData/KL/f02.wav
# process AudioData/KL/f03.wav
# process AudioData/KL/f04.wav
# process AudioData/KL/f05.wav
# process AudioData/KL/f06.wav
# process AudioData/KL/f07.wav
# process AudioData/KL/f08.wav
# process AudioData/KL/f09.wav
# process AudioData/KL/f10.wav
# process AudioData/KL/f11.wav
# process AudioData/KL/f12.wav
# process AudioData/KL/f13.wav
# process AudioData/KL/f14.wav
# process AudioData/KL/f15.wav
# process AudioData/KL/h01.wav
# process AudioData/KL/h02.wav
# process AudioData/KL/h03.wav
# process AudioData/KL/h04.wav
# process AudioData/KL/h05.wav
# process AudioData/KL/h06.wav
# process AudioData/KL/h07.wav
# process AudioData/KL/h08.wav
# process AudioData/KL/h09.wav
# process AudioData/KL/h10.wav
# process AudioData/KL/h11.wav
# process AudioData/KL/h12.wav
# process AudioData/KL/h13.wav
# process AudioData/KL/h14.wav
# process AudioData/KL/h15.wav
# process AudioData/KL/n01.wav
# process AudioData/KL/n02.wav
# process AudioData/KL/n03.wav
# process AudioData/KL/n04.wav
# process AudioData/KL/n05.wav
# process AudioData/KL/n06.wav
# process AudioData/KL/n07.wav
# process AudioData/KL/n08.wav
# process AudioData/KL/n09.wav
# process AudioData/KL/n10.wav
# process AudioData/KL/n11.wav
# process AudioData/KL/n12.wav
# process AudioData/KL/n13.wav
# process AudioData/KL/n14.wav
# process AudioData/KL/n15.wav
# process AudioData/KL/n16.wav
# process AudioData/KL/n17.wav
# process AudioData/KL/n18.wav
# process AudioData/KL/n19.wav
# process AudioData/KL/n20.wav
# process AudioData/KL/n21.wav
# process AudioData/KL/n22.wav
# process AudioData/KL/n23.wav
# process AudioData/KL/n24.wav
# process AudioData/KL/n25.wav
# process AudioData/KL/n26.wav
# process AudioData/KL/n27.wav
# process AudioData/KL/n28.wav
# process AudioData/KL/n29.wav
# process AudioData/KL/n30.wav
# process AudioData/KL/sa01.wav
# process AudioData/KL/sa02.wav
# process AudioData/KL/sa03.wav
# process AudioData/KL/sa04.wav
# process AudioData/KL/sa05.wav
# process AudioData/KL/sa06.wav
# process AudioData/KL/sa07.wav
# process AudioData/KL/sa08.wav
# process AudioData/KL/sa09.wav
# process AudioData/KL/sa10.wav
# process AudioData/KL/sa11.wav
# process AudioData/KL/sa12.wav
# process AudioData/KL/sa13.wav
# process AudioData/KL/sa14.wav
# process AudioData/KL/sa15.wav
# process AudioData/KL/su01.wav
# process AudioData/KL/su02.wav
# process AudioData/KL/su03.wav
# process AudioData/KL/su04.wav
# process AudioData/KL/su05.wav
# process AudioData/KL/su06.wav
# process AudioData/KL/su07.wav
# process AudioData/KL/su08.wav
# process AudioData/KL/su09.wav
# process AudioData/KL/su10.wav
# process AudioData/KL/su11.wav
# process AudioData/KL/su12.wav
# process AudioData/KL/su13.wav
# process AudioData/KL/su14.wav
# process AudioData/KL/su15.wav

# %%
df_features = pd.DataFrame.from_dict(features_dict, orient='index')

# %%
df_features = df.join(df_features)
print(df_features.head(5))
# Out:
#                                                 data                  path  \
# 1  [0.035011273, 0.052110124, 0.0455472, 0.049692...  AudioData/DC/a01.wav
# 2  [0.028584875, 0.043024283, 0.038623992, 0.0423...  AudioData/DC/a02.wav
# 3  [0.029121982, 0.043259364, 0.037821554, 0.0412...  AudioData/DC/a03.wav
# 4  [0.028819187, 0.042954646, 0.037683364, 0.0410...  AudioData/DC/a04.wav
# 5  [0.01032823, 0.015278679, 0.013250433, 0.01440...  AudioData/DC/a05.wav
#
#   dataset emotion speaker  augmented  \
# 1   SAVEE       a      DC      False
# 2   SAVEE       a      DC      False
# 3   SAVEE       a      DC      False
# 4   SAVEE       a      DC      False
# 5   SAVEE       a      DC      False
#
#                                                   f0  pitch_mean  \
# 1  [65.40639132514966, 168.66611791365605, 152.89...  148.356286
# 2  [65.40639132514966, 65.40639132514966, 221.274...  141.370603
# 3  [65.40639132514966, 160.1218501126406, 178.695...  184.753624
# 4  [65.40639132514966, 246.94165062806206, 245.51...  177.225990
# 5  [65.40639132514966, 221.27444703492776, 230.40...  163.306561
#
#    pitch_median  pitch_std  ...  \
# 1    148.110735  45.891830  ...
# 2    142.652351  30.057777  ...
# 3    189.321316  33.685440  ...
# 4    176.643034  38.360368  ...
# 5    165.768535  37.189306  ...
#
#                                            spec_flux  \
# 1  [0.0, 0.0, 0.0, 3.3515015, 0.02496624, 0.0, 0....
# 2  [0.0, 0.0, 0.0, 11.231688, 3.1098313, 0.0, 0.0...
# 3  [0.0, 0.0, 0.0, 3.6243677, 0.3538078, 0.0, 0.0...
# 4  [0.0, 0.0, 0.0, 0.0, 6.37982, 9.944395, 2.6369...
# 5  [0.0, 0.0, 0.0, 6.2058544, 3.9563394, 0.0, 0.0...
#
#                                        spec_centroid  \
# 1  [831.1022884035182, 680.349619471468, 640.2012...
# 2  [1568.4752157079797, 964.9598397254397, 839.69...
# 3  [1099.8088222205793, 669.1469972421936, 629.78...
# 4  [722.5552121998139, 604.7902796427356, 695.493...
# 5  [963.7519326183079, 877.4903743238758, 1004.56...
#
#                                       spec_bandwidth  \
# 1  [1477.456940511005, 990.4541419371847, 773.542...
# 2  [2215.2385451195305, 1384.5813199268177, 1122....
# 3  [2032.617465944953, 1004.5711220854784, 582.57...
# 4  [1355.0845476594732, 1006.249124589188, 903.28...
# 5  [1360.4698871041962, 1121.4856342689332, 1213....
#
#                                        spec_flatness  \
# 1  [0.0008953352, 0.00014590898, 4.2377296e-06, 8...
# 2  [0.005218329, 0.00045429962, 8.31512e-05, 3.72...
# 3  [0.0033986967, 0.00019356518, 4.4395637e-07, 8...
# 4  [0.00035139828, 4.385358e-05, 2.0128387e-05, 0...
# 5  [0.00034640462, 0.000109354754, 7.698751e-05, ...
#
#                                     power_spetrogram  \
# 1  [[28.240412, 33.4691, 34.330853, 34.37307, 34....
# 2  [[26.186691, 31.766495, 33.009926, 32.709106, ...
# 3  [[24.874899, 31.023579, 32.16931, 32.16562, 32...
# 4  [[27.177164, 31.667612, 31.45887, 27.962294, 1...
# 5  [[17.141342, 25.480757, 30.568144, 30.431675, ...
#
#                                       mel_spetrogram  \
# 1  [[1.6932554, 1.2244503, -0.1700051, -0.5826449...
# 2  [[1.5049081, 1.0788097, 1.2502325, 0.877231, -...
# 3  [[1.5778368, 1.2601149, -1.0044713, -1.0614277...
# 4  [[1.5836551, 0.93415534, 0.7294517, 0.90157384...
# 5  [[0.69334817, 1.2554052, 1.933363, 1.5390486, ...
#
#                                   mel_dB_spectrogram  \
# 1  [[-3.9216955, -5.329509, -80.0, -80.0, -80.0, ...
# 2  [[-4.5261655, -5.9718165, -5.3313575, -6.87012...
# 3  [[-4.144319, -5.120838, -80.0, -80.0, -80.0, -...
# 4  [[-4.7147694, -7.0071845, -8.08141, -7.1613626...
# 5  [[-8.25954, -5.681214, -3.8059192, -4.79653, -...
#
#                                                 mfcc  \
# 1  [[-219.52531, -193.17221, -200.38965, -219.389...
# 2  [[-267.86603, -136.18143, -103.8541, -143.0519...
# 3  [[-209.75467, -175.58162, -180.21672, -195.004...
# 4  [[-199.91661, -239.6453, -180.82625, -92.93551...
# 5  [[-214.52002, -136.7347, -98.54921, -120.9092,...
#
#                                           mfcc_delta  \
# 1  [[-2.3606448, -2.3606448, -2.3606448, -2.36064...
# 2  [[-0.5842052, -0.5842052, -0.5842052, -0.58420...
# 3  [[-2.1529448, -2.1529448, -2.1529448, -2.15294...
# 4  [[-15.755553, -15.755553, -15.755553, -15.7555...
# 5  [[-3.3275898, -3.3275898, -3.3275898, -3.32758...
#
#                                                  teo
# 1  [0.0, 0.0011411351, 0.00034040725, -0.00044772...
# 2  [0.0, -4.2640604e-06, 2.778368e-06, 4.637288e-...
# 3  [0.0, 0.00021470431, 0.00022272393, 0.00024402...
# 4  [0.0, -0.00021443237, -0.00036117155, 0.000128...
# 5  [0.0, 0.0011694788, 0.0005755767, 0.0001426881...
#
# [5 rows x 36 columns]

# %%
np.save(file="raw_audio_featrues_extraction_0324.npy", arr=df_features)
df_features.to_csv("raw_audio_featrues_extraction_0324.csv",index=False)

# %%
blob = bucket.blob('raw_audio_featrues_extraction_0324.npy')
blob.upload_from_filename('raw_audio_featrues_extraction_0324.npy')
blob = bucket.blob('raw_audio_featrues_extraction_0324.csv')
blob.upload_from_filename('raw_audio_featrues_extraction_0324.csv')
