# %% [markdown]
# **W207 MultiModal Learning for Emotion Recognition: Audio Feature + Video Feature**

# %%
# Import Modules
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from keras import backend as K
from keras.utils import np_utils
from matplotlib import pyplot as plt
from keras.constraints import maxnorm
from keras.utils import to_categorical
from sklearn.utils import class_weight
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from tensorflow.keras.models import Sequential, Model
from sklearn.model_selection import StratifiedGroupKFold
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, Flatten, Dense, MaxPool2D, AveragePooling2D, Concatenate,ConvLSTM2D
from sklearn.model_selection import cross_val_score
import keras
import sklearn
import matplotlib


print(np.__version__)
print(pd.__version__)
print(sns.__version__)
print(tf.__version__)
print(keras.__version__)
print(sklearn.__version__)
print(matplotlib.__version__)
# Out:
# 1.23.5
# 1.5.3
# 0.12.2
# 2.10.1
# 2.10.0
# 1.2.0
# 3.6.3

# %% [markdown]
# **Dataset Import and Dataframe Convert**

# %%
# === Dataset Path
dataset_path = "F:/Coding Projects/Data_Spell_Workspace/project_w207_video_process/Dataset/Process_4_MultiModal/audio_and_video.npy"
# === Import processed_data
source_data = np.load(dataset_path,allow_pickle=True)
# === print download
print("Dataset Loading Completed")
# === Convert NPY into Dataframes and print head(5)
df = pd.DataFrame(columns=["speaker","mfcc","mfcc_delta","video","augmented","emotion","path"])
for i in range(0,len(source_data)):
    df.loc[len(df)+1] = [source_data[i][0], source_data[i][1], source_data[i][2], source_data[i][3],source_data[i][4],source_data[i][5],source_data[i][6]]
label_dict = {"a":0,"n":1,"su":2,"sa":3,"d":4,"h":5,"f":6}
df["label_value"] = df["emotion"].replace(label_dict)
print("DataFrame Converted")
# Out:
# Dataset Loading Completed
# DataFrame Converted
#   speaker                                               mfcc  \
# 1      DC  [[-219.52531, -193.17221, -200.38965, -219.389...
# 2      DC  [[-418.1489669354606, -388.77411597771544, -38...
# 3      DC  [[-57.65764917727656, -18.372672911031955, -13...
# 4      DC  [[-482.4464, -456.09335, -463.3108, -482.31052...
# 5      DC  [[-267.86603, -136.18143, -103.85412, -143.051...
#
#                                           mfcc_delta  \
# 1  [[-2.3606448, -2.3606448, -2.3606448, -2.36064...
# 2  [[-1.7612268961686302, -1.7612268961686302, -1...
# 3  [[-2.582529147085004, -2.582529147085004, -2.5...
# 4  [[-2.360642, -2.360642, -2.360642, -2.360642, ...
# 5  [[-0.5842044, -0.5842044, -0.5842044, -0.58420...
#
#                                                video  augmented emotion  \
# 1  [[[[4 8 9], [3 7 8], [3 8 7], [4 9 8], [4 10 9...      False       a
# 2  [[[[4 8 9], [3 7 8], [3 8 7], [4 9 8], [4 10 9...       True       a
# 3  [[[[4 8 9], [3 7 8], [3 8 7], [4 9 8], [4 10 9...       True       a
# 4  [[[[4 8 9], [3 7 8], [3 8 7], [4 9 8], [4 10 9...       True       a
# 5  [[[[4 8 9], [4 8 9], [6 8 8], [7 9 9], [9 10 8...      False       a
#
#                    path  label_value
# 1  AudioData/DC/a01.wav            0
# 2  AudioData/DC/a01.wav            0
# 3  AudioData/DC/a01.wav            0
# 4  AudioData/DC/a01.wav            0
# 5  AudioData/DC/a02.wav            0

# %% [markdown]
# **Resizing Audio Features**

# %%
# Function: Get Maximum Size
def max_size(data):
    max_row_size = 0
    max_column_size = 0

    # Iterate through the Series to find the maximum row and column sizes
    for array in data:
        row_size, column_size = array.shape
        max_row_size = max(max_row_size, row_size)
        max_column_size = max(max_column_size, column_size)
    return max_row_size, max_column_size
# Function: Resizing the params
def resize(x):
    return np.pad(x, pad_width=((0, max_row_size - x.shape[0]),
                                (0, max_column_size - x.shape[1])),
                  mode='constant')

# === Resizing MFCC
max_row_size, max_column_size = max_size(df['mfcc'])
print(max_row_size, max_column_size)
df['mfcc'] = df['mfcc'].apply(resize)
max_row_size, max_column_size = max_size(df['mfcc_delta'])
print(max_row_size, max_column_size)
df['mfcc_delta'] = df['mfcc_delta'].apply(resize)
# Out:
# 40 290
# 40 290

# %% [markdown]
# **Function: Tensor Convert**

# %%
def train_test_processing(train_x_video,test_x_video,train_x_mfcc,test_x_mfcc,train_x_mfcc_delta,test_x_mfcc_delta,train_y,test_y):
    # === Convert df.columns into list
    train_x_video = [i for i in train_x_video]
    test_x_video = [i for i in test_x_video]
    train_x_mfcc = [i for i in train_x_mfcc]
    test_x_mfcc = [i for i in test_x_mfcc]
    train_x_mfcc_delta = [i for i in train_x_mfcc_delta]
    test_x_mfcc_delta = [i for i in test_x_mfcc_delta]
    train_y = [i for i in train_y]
    test_y = [i for i in test_y]

    # === Convert list into arrays
    train_x_video = np.array(train_x_video)
    test_x_video = np.array(test_x_video)
    train_x_mfcc = np.array(train_x_mfcc)
    test_x_mfcc = np.array(test_x_mfcc)
    train_x_mfcc_delta = np.array(train_x_mfcc_delta)
    test_x_mfcc_delta = np.array(test_x_mfcc_delta)
    train_y = np.array(train_y)
    test_y = np.array(test_y)


    # === Tensor Convert
    train_x_video = K.cast_to_floatx(train_x_video)
    test_x_video = K.cast_to_floatx(test_x_video)
    train_y = K.cast_to_floatx(train_y)
    test_y = K.cast_to_floatx(test_y)
    # Copy label list
    confusion_test_y = test_y
    class_weight_y = train_y

    # === Normalization
    train_x_video = train_x_video.astype('float32')
    test_x_video = test_x_video.astype('float32')
    train_x_video = train_x_video / 255.0
    test_x_video = test_x_video / 255.0
    train_x_mfcc = train_x_mfcc / 255.0
    test_x_mfcc = test_x_mfcc / 255.0
    train_x_mfcc_delta = train_x_mfcc_delta / 255.0
    test_x_mfcc_delta = test_x_mfcc_delta / 255.0

    # === One-hot Encoding
    train_y = np_utils.to_categorical(train_y)
    test_y = np_utils.to_categorical(test_y)
    class_num = test_y.shape[1]

    # === print result
    print("train_x_video: ", len(train_x_video))
    print("test_x_video: ", len(test_x_video))
    print("train_x_mfcc: ", len(train_x_mfcc))
    print("test_x_mfcc: ", len(test_x_mfcc))
    print("train_x_mfcc_delta: ", len(train_x_mfcc_delta))
    print("test_x_mfcc_delta: ", len(test_x_mfcc_delta))
    print("train_y: ", len(train_y))
    print("test_y: ", len(test_y))
    return train_x_video,test_x_video,train_x_mfcc,test_x_mfcc,train_x_mfcc_delta,test_x_mfcc_delta,train_y,test_y,confusion_test_y,class_weight_y

# %% [markdown]
# **Function: MultiModal Fusion Model Architecture**

# %%
# === Function: Model Construction
def build_model(n_classes, video_train, audio_train, optimizer, learning_rate):

    # === Initial model and set seed
    tf.keras.backend.clear_session()
    np.random.seed(0)
    tf.random.set_seed(0)


    # === Input A: Videos
    # Input Layer
    video_input = Input((6,64,64,3))
    # Layer 1: Convolutional LSTM Layer
    video_part = ConvLSTM2D(filters=32, kernel_size=(5, 5),input_shape = (6,64,64,3),activation='relu')(video_input)
    video_part = BatchNormalization()(video_part)
    # Layer 2: Convolutional Layer
    video_part = Conv2D(32, (3, 3),activation='relu')(video_part)
    video_part = MaxPool2D(2,2)(video_part)
    video_part = Dropout(0.2)(video_part)
    video_part = BatchNormalization()(video_part)
    # Flatten Layer
    video_part = Flatten()(video_part)
    # video_part = Dropout(0.2)(video_part)
    # Dense Layer
    video_part = Dense(16, kernel_constraint=maxnorm(3), kernel_regularizer=regularizers.l2(0.01),activation='relu')(video_part)
    # video_part = Dropout(0.2)(video_part)
    video_part = BatchNormalization()(video_part)


    # === Input B: Audios
    # Input Lauyer
    audio_input = Input((40, 290, 1))
    # Layer 1: Convolutional Layer
    audio_part = Conv2D(32, (5,5),activation='relu')(audio_input)
    audio_part = AveragePooling2D(3,3)(audio_part)
    audio_part = Dropout(0.2)(audio_part)
    audio_part = BatchNormalization()(audio_part)
    # Layer 2: Convolutional Layer
    audio_part = Conv2D(16, (3,3),activation='relu')(audio_part)
    audio_part = BatchNormalization()(audio_part)
    audio_part = MaxPool2D(2,2)(audio_part)
    # Flatten Layer
    audio_part = Flatten()(audio_part)
    # audio_part = Dropout(0.2)(audio_part)
    # Dense Layer
    audio_part = Dense(32, activation='relu')(audio_part)


    # === MultiModal: Video + Audio
    # Concatenation Layer
    Multimodal = Concatenate()([video_part, audio_part])
    # Layer 1: Dense Layer
    Multimodal = Dense(units=32, activation='relu')(Multimodal)
    Multimodal = Dropout(0.2)(Multimodal)
    Multimodal = BatchNormalization()(Multimodal)
    # Layer 2: Dense Layer
    Multimodal = Dense(units=32, activation='relu')(Multimodal)
    # Multimodal = Dropout(0.2)(Multimodal)
    Multimodal = BatchNormalization()(Multimodal)
    # Output Layer with Softmax
    output = Dense(units=n_classes, activation='softmax')(Multimodal)

    # Run Model
    model = Model(inputs=[video_input, audio_input], outputs=output)

    # Optimizers
    if optimizer == "SGD":
        model.compile(loss='categorical_crossentropy',
                      optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),
                      metrics=['accuracy'])
    elif optimizer == "Adam":
        model.compile(loss='categorical_crossentropy',
                      optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                      metrics=['accuracy'])

    # print model Architecture
    print(model.summary())

    # Return model result
    return model

# %% [markdown]
# **Function: Accuracy & Loss Diagram**

# %%
def Acc_Loss_diagram(counter):
    # === Summarize history for accuracy
    plt.plot(history.history['accuracy'],c ="darkcyan")
    plt.plot(history.history['val_accuracy'])
    plt.title('MultiModal - Accuracy Diagram CV' + str(counter))
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.grid(ls = "--", lw = 0.5, color = "#4E616C")
    plt.show()
    # === Summarize history for loss
    plt.plot(history.history['loss'],c ="darkcyan")
    plt.plot(history.history['val_loss'])
    plt.title('MultiModal - Loss Diagram CV' + str(counter))
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.grid(ls = "--", lw = 0.5, color = "#4E616C")
    plt.show()

# %% [markdown]
# **Cross Validation Model Training**

# %%
# Accuracy and Loss Save
train_accuracy = []
val_accuracy = []
train_loss = []
val_loss = []
# Prediction Save
test_y_dense= []
predict_y_total = []
test_y_one_hot = []
# counting Time
counter = 1

# === Group Stratified Dataset Train/Test Split
spliter = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=10)
for train_index, val_index in spliter.split(df.video, df.label_value, df.path):
    print("------------------ Cross Validation Training ------------------ ",counter)
    # Train / Test Split by Group
    train_x_video, test_x_video = df.video.iloc[train_index], df.video.iloc[val_index]
    train_x_mfcc, test_x_mfcc = df.mfcc.iloc[train_index], df.mfcc.iloc[val_index]
    train_x_mfcc_delta, test_x_mfcc_delta = df.mfcc_delta.iloc[train_index], df.mfcc_delta.iloc[val_index]
    # Labels Split
    train_y, test_y = df.label_value.iloc[train_index], df.label_value.iloc[val_index]

    # Train/Test Dataset Processing
    train_x_video,test_x_video,train_x_mfcc,test_x_mfcc,train_x_mfcc_delta,test_x_mfcc_delta,train_y,test_y,confusion_test_y,class_weight_y = train_test_processing(train_x_video,test_x_video,train_x_mfcc,test_x_mfcc,train_x_mfcc_delta,test_x_mfcc_delta,train_y,test_y)
    test_y_dense.append(confusion_test_y)
    test_y_one_hot.append(test_y)
    # === Balance weights for model training
    class_weights = class_weight.compute_class_weight(class_weight="balanced",classes=np.unique(class_weight_y),y = class_weight_y)
    class_weight_dict = dict(zip([x for x in np.unique(class_weight_y)], class_weights))
    # === Build the model
    model = build_model(n_classes=7, video_train = train_x_video, audio_train = train_x_mfcc, optimizer="Adam",learning_rate=0.00003)
    # === Train the model
    history = model.fit(x=[train_x_video, train_x_mfcc], y=train_y, class_weight=class_weight_dict, epochs=50, batch_size=20, validation_data=([test_x_video, test_x_mfcc], test_y))
    # Draw Accuracy and Loss
    Acc_Loss_diagram(counter)
    counter += 1
    predict_y_total.append(model.predict([test_x_video, test_x_mfcc]))
    # Append Score
    train_accuracy.append(history.history['accuracy'][-1])
    val_accuracy.append(history.history['val_accuracy'][-1])
    train_loss.append(history.history['loss'][-1])
    val_loss.append(history.history['val_loss'][-1])
# Out:
# ------------------ Cross Validation Training ------------------  1
# train_x_video:  1440
# test_x_video:  480
# train_x_mfcc:  1440
# test_x_mfcc:  480
# train_x_mfcc_delta:  1440
# test_x_mfcc_delta:  480
# train_y:  1440
# test_y:  480
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 6, 64, 64,   0           []
#                                 3)]
#
#  input_2 (InputLayer)           [(None, 40, 290, 1)  0           []
#                                 ]
#
#  conv_lstm2d (ConvLSTM2D)       (None, 60, 60, 32)   112128      ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 36, 286, 32)  832         ['input_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 60, 60, 32)  128         ['conv_lstm2d[0][0]']
#  alization)
#
#  average_pooling2d (AveragePool  (None, 12, 95, 32)  0           ['conv2d_1[0][0]']
#  ing2D)
#
#  conv2d (Conv2D)                (None, 58, 58, 32)   9248        ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 12, 95, 32)   0           ['average_pooling2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 29, 29, 32)   0           ['conv2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 12, 95, 32)  128         ['dropout_1[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 29, 29, 32)   0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 10, 93, 16)   4624        ['batch_normalization_3[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 29, 29, 32)  128         ['dropout[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 10, 93, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  flatten (Flatten)              (None, 26912)        0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 5, 46, 16)   0           ['batch_normalization_4[0][0]']
#
#  dense (Dense)                  (None, 16)           430608      ['flatten[0][0]']
#
#  flatten_1 (Flatten)            (None, 3680)         0           ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16)          64          ['dense[0][0]']
#  rmalization)
#
#  dense_1 (Dense)                (None, 32)           117792      ['flatten_1[0][0]']
#
#  concatenate (Concatenate)      (None, 48)           0           ['batch_normalization_2[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           1568        ['concatenate[0][0]']
#
#  dropout_2 (Dropout)            (None, 32)           0           ['dense_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32)          128         ['dropout_2[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 32)           1056        ['batch_normalization_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32)          128         ['dense_3[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 7)            231         ['batch_normalization_6[0][0]']
#
# ==================================================================================================
# Total params: 678,855
# Trainable params: 678,471
# Non-trainable params: 384
# __________________________________________________________________________________________________
# None
# Epoch 1/50
# 72/72 [==============================] - 5s 53ms/step - loss: 2.8193 - accuracy: 0.1576 - val_loss: 2.3760 - val_accuracy: 0.1083
# Epoch 2/50
# 72/72 [==============================] - 3s 45ms/step - loss: 2.4580 - accuracy: 0.2174 - val_loss: 2.4353 - val_accuracy: 0.1271
# Epoch 3/50
# 72/72 [==============================] - 3s 46ms/step - loss: 2.3627 - accuracy: 0.2493 - val_loss: 2.5451 - val_accuracy: 0.1083
# Epoch 4/50
# 72/72 [==============================] - 3s 47ms/step - loss: 2.2116 - accuracy: 0.3042 - val_loss: 2.6150 - val_accuracy: 0.0938
# Epoch 5/50
# 72/72 [==============================] - 3s 47ms/step - loss: 2.1076 - accuracy: 0.3521 - val_loss: 2.5055 - val_accuracy: 0.1104
# Epoch 6/50
# 72/72 [==============================] - 3s 47ms/step - loss: 1.9310 - accuracy: 0.3854 - val_loss: 2.2255 - val_accuracy: 0.2313
# Epoch 7/50
# 72/72 [==============================] - 3s 48ms/step - loss: 1.8407 - accuracy: 0.4458 - val_loss: 2.1912 - val_accuracy: 0.2354
# Epoch 8/50
# 72/72 [==============================] - 3s 46ms/step - loss: 1.7609 - accuracy: 0.4694 - val_loss: 1.9831 - val_accuracy: 0.2750
# Epoch 9/50
# 72/72 [==============================] - 19s 263ms/step - loss: 1.6746 - accuracy: 0.5090 - val_loss: 1.6966 - val_accuracy: 0.4625
# Epoch 10/50
# 72/72 [==============================] - 7s 100ms/step - loss: 1.6040 - accuracy: 0.5285 - val_loss: 1.4272 - val_accuracy: 0.6417
# Epoch 11/50
# 72/72 [==============================] - 5s 63ms/step - loss: 1.5343 - accuracy: 0.5535 - val_loss: 1.4405 - val_accuracy: 0.5875
# Epoch 12/50
# 72/72 [==============================] - 5s 66ms/step - loss: 1.4074 - accuracy: 0.6139 - val_loss: 1.3363 - val_accuracy: 0.6562
# Epoch 13/50
# 72/72 [==============================] - 5s 69ms/step - loss: 1.3748 - accuracy: 0.6361 - val_loss: 1.2385 - val_accuracy: 0.7083
# Epoch 14/50
# 72/72 [==============================] - 5s 65ms/step - loss: 1.3114 - accuracy: 0.6535 - val_loss: 1.1864 - val_accuracy: 0.7292
# Epoch 15/50
# 72/72 [==============================] - 5s 65ms/step - loss: 1.2316 - accuracy: 0.6951 - val_loss: 1.0968 - val_accuracy: 0.8083
# Epoch 16/50
# 72/72 [==============================] - 5s 64ms/step - loss: 1.1970 - accuracy: 0.7083 - val_loss: 1.0773 - val_accuracy: 0.7958
# Epoch 17/50
# 72/72 [==============================] - 5s 66ms/step - loss: 1.0761 - accuracy: 0.7597 - val_loss: 1.0216 - val_accuracy: 0.8375
# Epoch 18/50
# 72/72 [==============================] - 5s 65ms/step - loss: 1.0709 - accuracy: 0.7701 - val_loss: 0.9427 - val_accuracy: 0.8833
# Epoch 19/50
# 72/72 [==============================] - 5s 68ms/step - loss: 1.0179 - accuracy: 0.7819 - val_loss: 0.9205 - val_accuracy: 0.8687
# Epoch 20/50
# 72/72 [==============================] - 5s 64ms/step - loss: 0.9766 - accuracy: 0.7965 - val_loss: 0.8415 - val_accuracy: 0.8729
# Epoch 21/50
# 72/72 [==============================] - 5s 66ms/step - loss: 0.9419 - accuracy: 0.8104 - val_loss: 0.8797 - val_accuracy: 0.8813
# Epoch 22/50
# 72/72 [==============================] - 5s 66ms/step - loss: 0.9132 - accuracy: 0.8250 - val_loss: 0.7984 - val_accuracy: 0.9167
# Epoch 23/50
# 72/72 [==============================] - 5s 64ms/step - loss: 0.8694 - accuracy: 0.8542 - val_loss: 0.7557 - val_accuracy: 0.9104
# Epoch 24/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.8397 - accuracy: 0.8528 - val_loss: 0.7454 - val_accuracy: 0.9208
# Epoch 25/50
# 72/72 [==============================] - 5s 65ms/step - loss: 0.8330 - accuracy: 0.8597 - val_loss: 0.8155 - val_accuracy: 0.8792
# Epoch 26/50
# 72/72 [==============================] - 5s 66ms/step - loss: 0.8162 - accuracy: 0.8625 - val_loss: 0.7346 - val_accuracy: 0.9083
# Epoch 27/50
# 72/72 [==============================] - 5s 64ms/step - loss: 0.7741 - accuracy: 0.8778 - val_loss: 0.6806 - val_accuracy: 0.9438
# Epoch 28/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.7686 - accuracy: 0.8854 - val_loss: 0.6160 - val_accuracy: 0.9271
# Epoch 29/50
# 72/72 [==============================] - 5s 66ms/step - loss: 0.7229 - accuracy: 0.9021 - val_loss: 0.6202 - val_accuracy: 0.9375
# Epoch 30/50
# 72/72 [==============================] - 5s 67ms/step - loss: 0.7054 - accuracy: 0.9118 - val_loss: 0.6644 - val_accuracy: 0.9125
# Epoch 31/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.7127 - accuracy: 0.9062 - val_loss: 0.5959 - val_accuracy: 0.9479
# Epoch 32/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.6906 - accuracy: 0.9187 - val_loss: 0.5819 - val_accuracy: 0.9417
# Epoch 33/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.6548 - accuracy: 0.9292 - val_loss: 0.5510 - val_accuracy: 0.9500
# Epoch 34/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.6419 - accuracy: 0.9285 - val_loss: 0.5255 - val_accuracy: 0.9542
# Epoch 35/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.6343 - accuracy: 0.9229 - val_loss: 0.5344 - val_accuracy: 0.9646
# Epoch 36/50
# 72/72 [==============================] - 5s 64ms/step - loss: 0.6133 - accuracy: 0.9375 - val_loss: 0.5130 - val_accuracy: 0.9667
# Epoch 37/50
# 72/72 [==============================] - 5s 64ms/step - loss: 0.6075 - accuracy: 0.9410 - val_loss: 0.5448 - val_accuracy: 0.9521
# Epoch 38/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.5975 - accuracy: 0.9333 - val_loss: 0.5198 - val_accuracy: 0.9646
# Epoch 39/50
# 72/72 [==============================] - 5s 67ms/step - loss: 0.5938 - accuracy: 0.9451 - val_loss: 0.4868 - val_accuracy: 0.9729
# Epoch 40/50
# 72/72 [==============================] - 5s 64ms/step - loss: 0.5507 - accuracy: 0.9493 - val_loss: 0.5333 - val_accuracy: 0.9500
# Epoch 41/50
# 72/72 [==============================] - 5s 65ms/step - loss: 0.5633 - accuracy: 0.9493 - val_loss: 0.4893 - val_accuracy: 0.9604
# Epoch 42/50
# 72/72 [==============================] - 5s 65ms/step - loss: 0.5261 - accuracy: 0.9611 - val_loss: 0.4536 - val_accuracy: 0.9563
# Epoch 43/50
# 72/72 [==============================] - 5s 65ms/step - loss: 0.5367 - accuracy: 0.9521 - val_loss: 0.5164 - val_accuracy: 0.9646
# Epoch 44/50
# 72/72 [==============================] - 5s 65ms/step - loss: 0.5342 - accuracy: 0.9542 - val_loss: 0.4568 - val_accuracy: 0.9500
# Epoch 45/50
# 72/72 [==============================] - 5s 67ms/step - loss: 0.5250 - accuracy: 0.9549 - val_loss: 0.4820 - val_accuracy: 0.9563
# Epoch 46/50
# 72/72 [==============================] - 5s 65ms/step - loss: 0.4953 - accuracy: 0.9708 - val_loss: 0.4515 - val_accuracy: 0.9708
# Epoch 47/50
# 72/72 [==============================] - 5s 65ms/step - loss: 0.4920 - accuracy: 0.9660 - val_loss: 0.4425 - val_accuracy: 0.9583
# Epoch 48/50
# 72/72 [==============================] - 5s 65ms/step - loss: 0.4884 - accuracy: 0.9632 - val_loss: 0.4614 - val_accuracy: 0.9521
# Epoch 49/50
# 72/72 [==============================] - 5s 62ms/step - loss: 0.4768 - accuracy: 0.9618 - val_loss: 0.4341 - val_accuracy: 0.9417
# Epoch 50/50
# 72/72 [==============================] - 5s 64ms/step - loss: 0.4770 - accuracy: 0.9653 - val_loss: 0.4549 - val_accuracy: 0.9625
# 15/15 [==============================] - 1s 30ms/step
# ------------------ Cross Validation Training ------------------  2
# train_x_video:  1440
# test_x_video:  480
# train_x_mfcc:  1440
# test_x_mfcc:  480
# train_x_mfcc_delta:  1440
# test_x_mfcc_delta:  480
# train_y:  1440
# test_y:  480
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 6, 64, 64,   0           []
#                                 3)]
#
#  input_2 (InputLayer)           [(None, 40, 290, 1)  0           []
#                                 ]
#
#  conv_lstm2d (ConvLSTM2D)       (None, 60, 60, 32)   112128      ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 36, 286, 32)  832         ['input_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 60, 60, 32)  128         ['conv_lstm2d[0][0]']
#  alization)
#
#  average_pooling2d (AveragePool  (None, 12, 95, 32)  0           ['conv2d_1[0][0]']
#  ing2D)
#
#  conv2d (Conv2D)                (None, 58, 58, 32)   9248        ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 12, 95, 32)   0           ['average_pooling2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 29, 29, 32)   0           ['conv2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 12, 95, 32)  128         ['dropout_1[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 29, 29, 32)   0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 10, 93, 16)   4624        ['batch_normalization_3[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 29, 29, 32)  128         ['dropout[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 10, 93, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  flatten (Flatten)              (None, 26912)        0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 5, 46, 16)   0           ['batch_normalization_4[0][0]']
#
#  dense (Dense)                  (None, 16)           430608      ['flatten[0][0]']
#
#  flatten_1 (Flatten)            (None, 3680)         0           ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16)          64          ['dense[0][0]']
#  rmalization)
#
#  dense_1 (Dense)                (None, 32)           117792      ['flatten_1[0][0]']
#
#  concatenate (Concatenate)      (None, 48)           0           ['batch_normalization_2[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           1568        ['concatenate[0][0]']
#
#  dropout_2 (Dropout)            (None, 32)           0           ['dense_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32)          128         ['dropout_2[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 32)           1056        ['batch_normalization_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32)          128         ['dense_3[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 7)            231         ['batch_normalization_6[0][0]']
#
# ==================================================================================================
# Total params: 678,855
# Trainable params: 678,471
# Non-trainable params: 384
# __________________________________________________________________________________________________
# None
# Epoch 1/50
# 72/72 [==============================] - 7s 66ms/step - loss: 2.6149 - accuracy: 0.1924 - val_loss: 2.2919 - val_accuracy: 0.1333
# Epoch 2/50
# 72/72 [==============================] - 4s 63ms/step - loss: 2.2703 - accuracy: 0.2757 - val_loss: 2.3851 - val_accuracy: 0.1333
# Epoch 3/50
# 72/72 [==============================] - 4s 62ms/step - loss: 2.1922 - accuracy: 0.3097 - val_loss: 2.3569 - val_accuracy: 0.1333
# Epoch 4/50
# 72/72 [==============================] - 4s 62ms/step - loss: 2.0233 - accuracy: 0.3694 - val_loss: 2.2699 - val_accuracy: 0.1333
# Epoch 5/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.9344 - accuracy: 0.4021 - val_loss: 2.1675 - val_accuracy: 0.2688
# Epoch 6/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.8525 - accuracy: 0.4340 - val_loss: 2.0155 - val_accuracy: 0.3812
# Epoch 7/50
# 72/72 [==============================] - 5s 63ms/step - loss: 1.6963 - accuracy: 0.5021 - val_loss: 2.0045 - val_accuracy: 0.3500
# Epoch 8/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.6600 - accuracy: 0.5194 - val_loss: 1.7251 - val_accuracy: 0.5708
# Epoch 9/50
# 72/72 [==============================] - 4s 60ms/step - loss: 1.6104 - accuracy: 0.5486 - val_loss: 1.5383 - val_accuracy: 0.6333
# Epoch 10/50
# 72/72 [==============================] - 5s 63ms/step - loss: 1.5197 - accuracy: 0.5882 - val_loss: 1.4574 - val_accuracy: 0.6854
# Epoch 11/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.4417 - accuracy: 0.6160 - val_loss: 1.2646 - val_accuracy: 0.7437
# Epoch 12/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.3934 - accuracy: 0.6458 - val_loss: 1.2768 - val_accuracy: 0.7312
# Epoch 13/50
# 72/72 [==============================] - 5s 64ms/step - loss: 1.3315 - accuracy: 0.6687 - val_loss: 1.1983 - val_accuracy: 0.7458
# Epoch 14/50
# 72/72 [==============================] - 5s 63ms/step - loss: 1.2694 - accuracy: 0.6875 - val_loss: 1.1847 - val_accuracy: 0.7479
# Epoch 15/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.1900 - accuracy: 0.7333 - val_loss: 1.1688 - val_accuracy: 0.7375
# Epoch 16/50
# 72/72 [==============================] - 4s 61ms/step - loss: 1.1411 - accuracy: 0.7583 - val_loss: 1.0714 - val_accuracy: 0.8271
# Epoch 17/50
# 72/72 [==============================] - 5s 64ms/step - loss: 1.0850 - accuracy: 0.7785 - val_loss: 0.9682 - val_accuracy: 0.8271
# Epoch 18/50
# 72/72 [==============================] - 5s 64ms/step - loss: 1.0236 - accuracy: 0.8007 - val_loss: 0.9403 - val_accuracy: 0.8208
# Epoch 19/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.9443 - accuracy: 0.8319 - val_loss: 0.8945 - val_accuracy: 0.8708
# Epoch 20/50
# 72/72 [==============================] - 5s 64ms/step - loss: 0.9341 - accuracy: 0.8326 - val_loss: 0.8310 - val_accuracy: 0.9021
# Epoch 21/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.9187 - accuracy: 0.8438 - val_loss: 0.8508 - val_accuracy: 0.8667
# Epoch 22/50
# 72/72 [==============================] - 4s 60ms/step - loss: 0.8374 - accuracy: 0.8778 - val_loss: 0.7543 - val_accuracy: 0.9104
# Epoch 23/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.8413 - accuracy: 0.8743 - val_loss: 0.7663 - val_accuracy: 0.8875
# Epoch 24/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.8061 - accuracy: 0.8958 - val_loss: 0.7044 - val_accuracy: 0.9292
# Epoch 25/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.7852 - accuracy: 0.8986 - val_loss: 0.7190 - val_accuracy: 0.9208
# Epoch 26/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.7523 - accuracy: 0.9187 - val_loss: 0.6806 - val_accuracy: 0.9208
# Epoch 27/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.7401 - accuracy: 0.9104 - val_loss: 0.6928 - val_accuracy: 0.9125
# Epoch 28/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.7248 - accuracy: 0.9153 - val_loss: 0.6724 - val_accuracy: 0.9354
# Epoch 29/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.6784 - accuracy: 0.9326 - val_loss: 0.5814 - val_accuracy: 0.9417
# Epoch 30/50
# 72/72 [==============================] - 5s 65ms/step - loss: 0.6770 - accuracy: 0.9201 - val_loss: 0.5635 - val_accuracy: 0.9479
# Epoch 31/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.6740 - accuracy: 0.9264 - val_loss: 0.5536 - val_accuracy: 0.9583
# Epoch 32/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.6428 - accuracy: 0.9444 - val_loss: 0.5356 - val_accuracy: 0.9583
# Epoch 33/50
# 72/72 [==============================] - 5s 64ms/step - loss: 0.6219 - accuracy: 0.9431 - val_loss: 0.5375 - val_accuracy: 0.9646
# Epoch 34/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5946 - accuracy: 0.9528 - val_loss: 0.5559 - val_accuracy: 0.9500
# Epoch 35/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5851 - accuracy: 0.9528 - val_loss: 0.5388 - val_accuracy: 0.9604
# Epoch 36/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.5802 - accuracy: 0.9458 - val_loss: 0.5169 - val_accuracy: 0.9625
# Epoch 37/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.5707 - accuracy: 0.9535 - val_loss: 0.5203 - val_accuracy: 0.9500
# Epoch 38/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.5564 - accuracy: 0.9549 - val_loss: 0.5175 - val_accuracy: 0.9271
# Epoch 39/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.5350 - accuracy: 0.9632 - val_loss: 0.4960 - val_accuracy: 0.9521
# Epoch 40/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5324 - accuracy: 0.9674 - val_loss: 0.4761 - val_accuracy: 0.9563
# Epoch 41/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5242 - accuracy: 0.9646 - val_loss: 0.4647 - val_accuracy: 0.9667
# Epoch 42/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5106 - accuracy: 0.9681 - val_loss: 0.5755 - val_accuracy: 0.9312
# Epoch 43/50
# 72/72 [==============================] - 5s 64ms/step - loss: 0.5270 - accuracy: 0.9486 - val_loss: 0.4527 - val_accuracy: 0.9604
# Epoch 44/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5190 - accuracy: 0.9576 - val_loss: 0.4372 - val_accuracy: 0.9833
# Epoch 45/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.4853 - accuracy: 0.9653 - val_loss: 0.4492 - val_accuracy: 0.9583
# Epoch 46/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.4632 - accuracy: 0.9722 - val_loss: 0.4471 - val_accuracy: 0.9542
# Epoch 47/50
# 72/72 [==============================] - 5s 64ms/step - loss: 0.4612 - accuracy: 0.9750 - val_loss: 0.4565 - val_accuracy: 0.9521
# Epoch 48/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.4565 - accuracy: 0.9681 - val_loss: 0.4494 - val_accuracy: 0.9542
# Epoch 49/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.4480 - accuracy: 0.9757 - val_loss: 0.4349 - val_accuracy: 0.9563
# Epoch 50/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.4497 - accuracy: 0.9694 - val_loss: 0.3895 - val_accuracy: 0.9729
# 15/15 [==============================] - 1s 32ms/step
# ------------------ Cross Validation Training ------------------  3
# train_x_video:  1440
# test_x_video:  480
# train_x_mfcc:  1440
# test_x_mfcc:  480
# train_x_mfcc_delta:  1440
# test_x_mfcc_delta:  480
# train_y:  1440
# test_y:  480
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 6, 64, 64,   0           []
#                                 3)]
#
#  input_2 (InputLayer)           [(None, 40, 290, 1)  0           []
#                                 ]
#
#  conv_lstm2d (ConvLSTM2D)       (None, 60, 60, 32)   112128      ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 36, 286, 32)  832         ['input_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 60, 60, 32)  128         ['conv_lstm2d[0][0]']
#  alization)
#
#  average_pooling2d (AveragePool  (None, 12, 95, 32)  0           ['conv2d_1[0][0]']
#  ing2D)
#
#  conv2d (Conv2D)                (None, 58, 58, 32)   9248        ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 12, 95, 32)   0           ['average_pooling2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 29, 29, 32)   0           ['conv2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 12, 95, 32)  128         ['dropout_1[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 29, 29, 32)   0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 10, 93, 16)   4624        ['batch_normalization_3[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 29, 29, 32)  128         ['dropout[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 10, 93, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  flatten (Flatten)              (None, 26912)        0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 5, 46, 16)   0           ['batch_normalization_4[0][0]']
#
#  dense (Dense)                  (None, 16)           430608      ['flatten[0][0]']
#
#  flatten_1 (Flatten)            (None, 3680)         0           ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16)          64          ['dense[0][0]']
#  rmalization)
#
#  dense_1 (Dense)                (None, 32)           117792      ['flatten_1[0][0]']
#
#  concatenate (Concatenate)      (None, 48)           0           ['batch_normalization_2[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           1568        ['concatenate[0][0]']
#
#  dropout_2 (Dropout)            (None, 32)           0           ['dense_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32)          128         ['dropout_2[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 32)           1056        ['batch_normalization_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32)          128         ['dense_3[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 7)            231         ['batch_normalization_6[0][0]']
#
# ==================================================================================================
# Total params: 678,855
# Trainable params: 678,471
# Non-trainable params: 384
# __________________________________________________________________________________________________
# None
# Epoch 1/50
# 72/72 [==============================] - 7s 67ms/step - loss: 2.8660 - accuracy: 0.1292 - val_loss: 2.2800 - val_accuracy: 0.1417
# Epoch 2/50
# 72/72 [==============================] - 4s 61ms/step - loss: 2.7082 - accuracy: 0.1576 - val_loss: 2.3251 - val_accuracy: 0.1417
# Epoch 3/50
# 72/72 [==============================] - 4s 61ms/step - loss: 2.6025 - accuracy: 0.1931 - val_loss: 2.3638 - val_accuracy: 0.1542
# Epoch 4/50
# 72/72 [==============================] - 4s 60ms/step - loss: 2.5040 - accuracy: 0.2146 - val_loss: 2.2909 - val_accuracy: 0.1937
# Epoch 5/50
# 72/72 [==============================] - 4s 62ms/step - loss: 2.4006 - accuracy: 0.2319 - val_loss: 2.2611 - val_accuracy: 0.2313
# Epoch 6/50
# 72/72 [==============================] - 4s 60ms/step - loss: 2.2595 - accuracy: 0.2604 - val_loss: 2.1970 - val_accuracy: 0.2313
# Epoch 7/50
# 72/72 [==============================] - 4s 61ms/step - loss: 2.2012 - accuracy: 0.2806 - val_loss: 2.1654 - val_accuracy: 0.2542
# Epoch 8/50
# 72/72 [==============================] - 4s 61ms/step - loss: 2.1001 - accuracy: 0.3146 - val_loss: 1.9643 - val_accuracy: 0.3396
# Epoch 9/50
# 72/72 [==============================] - 4s 62ms/step - loss: 2.1264 - accuracy: 0.2979 - val_loss: 2.0065 - val_accuracy: 0.3063
# Epoch 10/50
# 72/72 [==============================] - 5s 63ms/step - loss: 2.0826 - accuracy: 0.3208 - val_loss: 2.0075 - val_accuracy: 0.3063
# Epoch 11/50
# 72/72 [==============================] - 4s 60ms/step - loss: 2.0389 - accuracy: 0.3264 - val_loss: 1.8888 - val_accuracy: 0.4250
# Epoch 12/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.9399 - accuracy: 0.3736 - val_loss: 1.7923 - val_accuracy: 0.4875
# Epoch 13/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.8962 - accuracy: 0.4000 - val_loss: 1.7740 - val_accuracy: 0.4229
# Epoch 14/50
# 72/72 [==============================] - 4s 61ms/step - loss: 1.8544 - accuracy: 0.4083 - val_loss: 1.7480 - val_accuracy: 0.4625
# Epoch 15/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.7113 - accuracy: 0.4646 - val_loss: 1.6535 - val_accuracy: 0.5167
# Epoch 16/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.7329 - accuracy: 0.4479 - val_loss: 1.5234 - val_accuracy: 0.6042
# Epoch 17/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.6465 - accuracy: 0.4688 - val_loss: 1.5433 - val_accuracy: 0.6042
# Epoch 18/50
# 72/72 [==============================] - 4s 61ms/step - loss: 1.6072 - accuracy: 0.5007 - val_loss: 1.4689 - val_accuracy: 0.6333
# Epoch 19/50
# 72/72 [==============================] - 5s 64ms/step - loss: 1.5289 - accuracy: 0.5389 - val_loss: 1.4505 - val_accuracy: 0.6708
# Epoch 20/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.5072 - accuracy: 0.5542 - val_loss: 1.4234 - val_accuracy: 0.6604
# Epoch 21/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.4927 - accuracy: 0.5771 - val_loss: 1.3052 - val_accuracy: 0.7188
# Epoch 22/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.3994 - accuracy: 0.6069 - val_loss: 1.3062 - val_accuracy: 0.7542
# Epoch 23/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.3680 - accuracy: 0.6319 - val_loss: 1.1530 - val_accuracy: 0.8083
# Epoch 24/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.3394 - accuracy: 0.6465 - val_loss: 1.1905 - val_accuracy: 0.7750
# Epoch 25/50
# 72/72 [==============================] - 5s 63ms/step - loss: 1.2976 - accuracy: 0.6618 - val_loss: 1.1119 - val_accuracy: 0.8000
# Epoch 26/50
# 72/72 [==============================] - 5s 63ms/step - loss: 1.2701 - accuracy: 0.6833 - val_loss: 1.0819 - val_accuracy: 0.8271
# Epoch 27/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.1898 - accuracy: 0.7396 - val_loss: 1.0515 - val_accuracy: 0.8521
# Epoch 28/50
# 72/72 [==============================] - 4s 61ms/step - loss: 1.1714 - accuracy: 0.7333 - val_loss: 1.0972 - val_accuracy: 0.8125
# Epoch 29/50
# 72/72 [==============================] - 5s 63ms/step - loss: 1.1061 - accuracy: 0.7514 - val_loss: 0.9895 - val_accuracy: 0.8604
# Epoch 30/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.0653 - accuracy: 0.7826 - val_loss: 0.9638 - val_accuracy: 0.8833
# Epoch 31/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.0638 - accuracy: 0.7924 - val_loss: 0.9391 - val_accuracy: 0.8417
# Epoch 32/50
# 72/72 [==============================] - 5s 64ms/step - loss: 1.0321 - accuracy: 0.7924 - val_loss: 0.8395 - val_accuracy: 0.9104
# Epoch 33/50
# 72/72 [==============================] - 5s 67ms/step - loss: 1.0076 - accuracy: 0.8035 - val_loss: 0.9137 - val_accuracy: 0.8896
# Epoch 34/50
# 72/72 [==============================] - 5s 66ms/step - loss: 0.9584 - accuracy: 0.8250 - val_loss: 0.8329 - val_accuracy: 0.9271
# Epoch 35/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.9250 - accuracy: 0.8368 - val_loss: 0.8005 - val_accuracy: 0.9250
# Epoch 36/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.8762 - accuracy: 0.8535 - val_loss: 0.7716 - val_accuracy: 0.9187
# Epoch 37/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.8878 - accuracy: 0.8569 - val_loss: 0.7690 - val_accuracy: 0.9563
# Epoch 38/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.8611 - accuracy: 0.8556 - val_loss: 0.6753 - val_accuracy: 0.9417
# Epoch 39/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.8174 - accuracy: 0.8847 - val_loss: 0.6596 - val_accuracy: 0.9500
# Epoch 40/50
# 72/72 [==============================] - 5s 64ms/step - loss: 0.7866 - accuracy: 0.8854 - val_loss: 0.6881 - val_accuracy: 0.9438
# Epoch 41/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.7816 - accuracy: 0.8806 - val_loss: 0.6398 - val_accuracy: 0.9563
# Epoch 42/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.7445 - accuracy: 0.8993 - val_loss: 0.6161 - val_accuracy: 0.9604
# Epoch 43/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.7216 - accuracy: 0.9069 - val_loss: 0.5871 - val_accuracy: 0.9646
# Epoch 44/50
# 72/72 [==============================] - 5s 64ms/step - loss: 0.7333 - accuracy: 0.8965 - val_loss: 0.5923 - val_accuracy: 0.9479
# Epoch 45/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.7123 - accuracy: 0.9201 - val_loss: 0.5905 - val_accuracy: 0.9521
# Epoch 46/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.6822 - accuracy: 0.9167 - val_loss: 0.5269 - val_accuracy: 0.9625
# Epoch 47/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.6653 - accuracy: 0.9167 - val_loss: 0.5651 - val_accuracy: 0.9500
# Epoch 48/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.6286 - accuracy: 0.9340 - val_loss: 0.5202 - val_accuracy: 0.9625
# Epoch 49/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.6256 - accuracy: 0.9375 - val_loss: 0.5375 - val_accuracy: 0.9375
# Epoch 50/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.6204 - accuracy: 0.9319 - val_loss: 0.4869 - val_accuracy: 0.9771
# 15/15 [==============================] - 1s 32ms/step
# ------------------ Cross Validation Training ------------------  4
# train_x_video:  1440
# test_x_video:  480
# train_x_mfcc:  1440
# test_x_mfcc:  480
# train_x_mfcc_delta:  1440
# test_x_mfcc_delta:  480
# train_y:  1440
# test_y:  480
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 6, 64, 64,   0           []
#                                 3)]
#
#  input_2 (InputLayer)           [(None, 40, 290, 1)  0           []
#                                 ]
#
#  conv_lstm2d (ConvLSTM2D)       (None, 60, 60, 32)   112128      ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 36, 286, 32)  832         ['input_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 60, 60, 32)  128         ['conv_lstm2d[0][0]']
#  alization)
#
#  average_pooling2d (AveragePool  (None, 12, 95, 32)  0           ['conv2d_1[0][0]']
#  ing2D)
#
#  conv2d (Conv2D)                (None, 58, 58, 32)   9248        ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 12, 95, 32)   0           ['average_pooling2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 29, 29, 32)   0           ['conv2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 12, 95, 32)  128         ['dropout_1[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 29, 29, 32)   0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 10, 93, 16)   4624        ['batch_normalization_3[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 29, 29, 32)  128         ['dropout[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 10, 93, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  flatten (Flatten)              (None, 26912)        0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 5, 46, 16)   0           ['batch_normalization_4[0][0]']
#
#  dense (Dense)                  (None, 16)           430608      ['flatten[0][0]']
#
#  flatten_1 (Flatten)            (None, 3680)         0           ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16)          64          ['dense[0][0]']
#  rmalization)
#
#  dense_1 (Dense)                (None, 32)           117792      ['flatten_1[0][0]']
#
#  concatenate (Concatenate)      (None, 48)           0           ['batch_normalization_2[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           1568        ['concatenate[0][0]']
#
#  dropout_2 (Dropout)            (None, 32)           0           ['dense_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32)          128         ['dropout_2[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 32)           1056        ['batch_normalization_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32)          128         ['dense_3[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 7)            231         ['batch_normalization_6[0][0]']
#
# ==================================================================================================
# Total params: 678,855
# Trainable params: 678,471
# Non-trainable params: 384
# __________________________________________________________________________________________________
# None
# Epoch 1/50
# 72/72 [==============================] - 7s 66ms/step - loss: 2.6389 - accuracy: 0.2111 - val_loss: 2.2959 - val_accuracy: 0.1417
# Epoch 2/50
# 72/72 [==============================] - 4s 61ms/step - loss: 2.3580 - accuracy: 0.2931 - val_loss: 2.3234 - val_accuracy: 0.1417
# Epoch 3/50
# 72/72 [==============================] - 5s 63ms/step - loss: 2.1396 - accuracy: 0.3576 - val_loss: 2.3493 - val_accuracy: 0.1417
# Epoch 4/50
# 72/72 [==============================] - 4s 61ms/step - loss: 1.9864 - accuracy: 0.4160 - val_loss: 2.3661 - val_accuracy: 0.1417
# Epoch 5/50
# 72/72 [==============================] - 4s 60ms/step - loss: 1.8926 - accuracy: 0.4368 - val_loss: 2.3196 - val_accuracy: 0.1896
# Epoch 6/50
# 72/72 [==============================] - 4s 61ms/step - loss: 1.7634 - accuracy: 0.4882 - val_loss: 2.1537 - val_accuracy: 0.2229
# Epoch 7/50
# 72/72 [==============================] - 4s 62ms/step - loss: 1.6737 - accuracy: 0.5340 - val_loss: 2.2015 - val_accuracy: 0.2812
# Epoch 8/50
# 72/72 [==============================] - 5s 68ms/step - loss: 1.5213 - accuracy: 0.5924 - val_loss: 1.8502 - val_accuracy: 0.4208
# Epoch 9/50
# 72/72 [==============================] - 5s 68ms/step - loss: 1.5076 - accuracy: 0.5931 - val_loss: 1.5698 - val_accuracy: 0.5813
# Epoch 10/50
# 72/72 [==============================] - 4s 60ms/step - loss: 1.3803 - accuracy: 0.6507 - val_loss: 1.4506 - val_accuracy: 0.6375
# Epoch 11/50
# 72/72 [==============================] - 4s 60ms/step - loss: 1.2329 - accuracy: 0.7174 - val_loss: 1.1844 - val_accuracy: 0.7937
# Epoch 12/50
# 72/72 [==============================] - 4s 60ms/step - loss: 1.2022 - accuracy: 0.7424 - val_loss: 1.1278 - val_accuracy: 0.7937
# Epoch 13/50
# 72/72 [==============================] - 5s 64ms/step - loss: 1.1377 - accuracy: 0.7479 - val_loss: 1.0462 - val_accuracy: 0.8458
# Epoch 14/50
# 72/72 [==============================] - 4s 61ms/step - loss: 1.1044 - accuracy: 0.7757 - val_loss: 0.9914 - val_accuracy: 0.8542
# Epoch 15/50
# 72/72 [==============================] - 4s 60ms/step - loss: 1.0507 - accuracy: 0.7896 - val_loss: 0.9494 - val_accuracy: 0.8667
# Epoch 16/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.9863 - accuracy: 0.8326 - val_loss: 0.9185 - val_accuracy: 0.8750
# Epoch 17/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.9276 - accuracy: 0.8549 - val_loss: 0.8641 - val_accuracy: 0.8917
# Epoch 18/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.9274 - accuracy: 0.8354 - val_loss: 0.8501 - val_accuracy: 0.8958
# Epoch 19/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.8650 - accuracy: 0.8799 - val_loss: 0.8143 - val_accuracy: 0.9292
# Epoch 20/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.8295 - accuracy: 0.8771 - val_loss: 0.7751 - val_accuracy: 0.9167
# Epoch 21/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.8152 - accuracy: 0.8771 - val_loss: 0.7604 - val_accuracy: 0.9062
# Epoch 22/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.7865 - accuracy: 0.8972 - val_loss: 0.7509 - val_accuracy: 0.9375
# Epoch 23/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.7766 - accuracy: 0.8986 - val_loss: 0.7358 - val_accuracy: 0.9271
# Epoch 24/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.7362 - accuracy: 0.9118 - val_loss: 0.7407 - val_accuracy: 0.9062
# Epoch 25/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.7082 - accuracy: 0.9194 - val_loss: 0.6751 - val_accuracy: 0.9333
# Epoch 26/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.7012 - accuracy: 0.9243 - val_loss: 0.6610 - val_accuracy: 0.9438
# Epoch 27/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.6841 - accuracy: 0.9299 - val_loss: 0.6512 - val_accuracy: 0.9479
# Epoch 28/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.6717 - accuracy: 0.9243 - val_loss: 0.6871 - val_accuracy: 0.9208
# Epoch 29/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.6521 - accuracy: 0.9382 - val_loss: 0.6206 - val_accuracy: 0.9438
# Epoch 30/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.6368 - accuracy: 0.9326 - val_loss: 0.6367 - val_accuracy: 0.9438
# Epoch 31/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.6379 - accuracy: 0.9340 - val_loss: 0.6361 - val_accuracy: 0.9354
# Epoch 32/50
# 72/72 [==============================] - 4s 60ms/step - loss: 0.6300 - accuracy: 0.9396 - val_loss: 0.6431 - val_accuracy: 0.9417
# Epoch 33/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5916 - accuracy: 0.9493 - val_loss: 0.6142 - val_accuracy: 0.9417
# Epoch 34/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.5815 - accuracy: 0.9569 - val_loss: 0.6215 - val_accuracy: 0.9500
# Epoch 35/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5671 - accuracy: 0.9479 - val_loss: 0.6100 - val_accuracy: 0.9667
# Epoch 36/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5606 - accuracy: 0.9535 - val_loss: 0.5522 - val_accuracy: 0.9688
# Epoch 37/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.5482 - accuracy: 0.9528 - val_loss: 0.5734 - val_accuracy: 0.9688
# Epoch 38/50
# 72/72 [==============================] - 4s 61ms/step - loss: 0.5509 - accuracy: 0.9535 - val_loss: 0.5421 - val_accuracy: 0.9479
# Epoch 39/50
# 72/72 [==============================] - 4s 60ms/step - loss: 0.5224 - accuracy: 0.9611 - val_loss: 0.5368 - val_accuracy: 0.9542
# Epoch 40/50
# 72/72 [==============================] - 5s 66ms/step - loss: 0.5036 - accuracy: 0.9674 - val_loss: 0.5267 - val_accuracy: 0.9563
# Epoch 41/50
# 72/72 [==============================] - 5s 72ms/step - loss: 0.5033 - accuracy: 0.9674 - val_loss: 0.5239 - val_accuracy: 0.9521
# Epoch 42/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.5138 - accuracy: 0.9569 - val_loss: 0.5204 - val_accuracy: 0.9583
# Epoch 43/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.5017 - accuracy: 0.9611 - val_loss: 0.5388 - val_accuracy: 0.9479
# Epoch 44/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.4949 - accuracy: 0.9597 - val_loss: 0.5065 - val_accuracy: 0.9729
# Epoch 45/50
# 72/72 [==============================] - 5s 65ms/step - loss: 0.4684 - accuracy: 0.9708 - val_loss: 0.5209 - val_accuracy: 0.9563
# Epoch 46/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.4691 - accuracy: 0.9688 - val_loss: 0.4831 - val_accuracy: 0.9417
# Epoch 47/50
# 72/72 [==============================] - 4s 62ms/step - loss: 0.4599 - accuracy: 0.9701 - val_loss: 0.5213 - val_accuracy: 0.9417
# Epoch 48/50
# 72/72 [==============================] - 5s 65ms/step - loss: 0.4510 - accuracy: 0.9729 - val_loss: 0.4842 - val_accuracy: 0.9625
# Epoch 49/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.4446 - accuracy: 0.9771 - val_loss: 0.4794 - val_accuracy: 0.9500
# Epoch 50/50
# 72/72 [==============================] - 5s 63ms/step - loss: 0.4598 - accuracy: 0.9646 - val_loss: 0.4581 - val_accuracy: 0.9667
# 15/15 [==============================] - 1s 30ms/step

# %% [markdown]
# **Performance Evaluation: Cross Validation Accuracy and Loss**

# %%
# === Print Cross validation Result
print("----------- Cross Validation Detail Result -----------")
print("Training Accuracy: ",train_accuracy)
print("Validation Accuracy: ",val_accuracy)
print("Training Loss: ",train_loss)
print("Validation Loss: ",val_loss)
print("----------- Cross Validation Result -----------")
print('Cross Validation Training Accuracy: %.3f +/- %.3f' % (np.mean(train_accuracy),np.std(train_accuracy)))
print('Cross Validation Validation Accuracy: %.3f +/- %.3f' % (np.mean(val_accuracy),np.std(val_accuracy)))
print('Cross Validation Training Loss: %.3f +/- %.3f' % (np.mean(train_loss),np.std(train_loss)))
print('Cross Validation Validation Loss: %.3f +/- %.3f' % (np.mean(val_loss),np.std(val_loss)))
# Out:
# ----------- Cross Validation Detail Result -----------
# Training Accuracy:  [0.9652777910232544, 0.9694444537162781, 0.9319444298744202, 0.9645833373069763]
# Validation Accuracy:  [0.9624999761581421, 0.9729166626930237, 0.9770833253860474, 0.9666666388511658]
# Training Loss:  [0.4770142436027527, 0.4497148394584656, 0.6203882098197937, 0.45980724692344666]
# Validation Loss:  [0.45490944385528564, 0.3894801735877991, 0.486939936876297, 0.45810797810554504]
# ----------- Cross Validation Result -----------
# Cross Validation Training Accuracy: 0.958 +/- 0.015
# Cross Validation Validation Accuracy: 0.970 +/- 0.006
# Cross Validation Training Loss: 0.502 +/- 0.069
# Cross Validation Validation Loss: 0.447 +/- 0.036

# %% [markdown]
# **Performance Evaluation: AUC ROC**

# %%
# === Concatenate values
convert_test_y_one_hot = np.concatenate((test_y_one_hot[0],test_y_one_hot[1],test_y_one_hot[2],test_y_one_hot[3]))
convert_predict_y_total = np.concatenate((predict_y_total[0],predict_y_total[1],predict_y_total[2],predict_y_total[3]))

# === Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(convert_test_y_one_hot[:, i], convert_predict_y_total[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

label_dict = {"Anger":0,"Neutral":1,"Surprise":2,"Sadness":3,"Disgust":4,"Happy":5,"Fear":6}
label_name = {v:k for k,v in label_dict.items()}
# Plot in one diagram
fig, ax = plt.subplots()
ax.plot([0, 1], [0, 1], 'k--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC AUC Diagram Summary')
for i in range(7):
    ax.plot(fpr[i], tpr[i], label='ROC curve (area ='+str(round(roc_auc[i],3))+') for label: '+label_name[i])
ax.legend(loc="best")
ax.grid(alpha=.4)
sns.despine()

# Plot AUC ROC individually
for i in range(7):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area ='+str(round(roc_auc[i],3))+') for label: '+label_name[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC AUC Diagram')
    plt.legend(loc="lower right")

# %% [markdown]
# **Performance Evaluation: Confusion Matrix & Classification Report**

# %%
# === Concatenate values
convert_test_y_dense = np.concatenate((test_y_dense[0],test_y_dense[1],test_y_dense[2],test_y_dense[3]))
convert_y_test_pred = np.concatenate((predict_y_total[0],predict_y_total[1],predict_y_total[2],predict_y_total[3]))

#  === Print confusion matrix
# y_test_pred = model.predict([test_x_video, test_x_mfcc])
y_test_pred = np.argmax(convert_y_test_pred, axis=1)
# Classification Report
print(classification_report(convert_test_y_dense, y_test_pred))
# Confusiont Matrix
target_names = ["A","N","SU","SA","D","H","F"]
cm_display = ConfusionMatrixDisplay.from_predictions(convert_test_y_dense, y_test_pred, display_labels=target_names,cmap = 'Blues')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.96      0.97       240
#          1.0       1.00      1.00      1.00       480
#          2.0       0.98      0.97      0.98       240
#          3.0       0.95      0.93      0.94       240
#          4.0       0.98      1.00      0.99       240
#          5.0       0.94      1.00      0.97       240
#          6.0       0.92      0.90      0.91       240
#
#     accuracy                           0.97      1920
#    macro avg       0.97      0.97      0.97      1920
# weighted avg       0.97      0.97      0.97      1920
